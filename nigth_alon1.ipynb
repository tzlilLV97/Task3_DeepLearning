# %% [markdown]
# <a href="https://colab.research.google.com/github/tzlilLV97/Task3_DeepLearning/blob/main/nigth_alon1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Alon Feldman 312213135**
#
# **Tzlil Lev-or 318646510**

# %% [markdown]
# # Assignment 3: Image Classification
#
# **Assignment Responsible**: Natalie Lang.
#
# In this assignment, we will build a convolutional neural network that can predict
# whether two shoes are from the **same pair** or from two **different pairs**.
# This kind of application can have real-world applications: for example to help
# people who are visually impaired to have more independence.
#
# We will explore two convolutional architectures. While we will give you starter
# code to help make data processing a bit easier, in this assignment you have a chance to build your neural network all by yourself.
#
# You may modify the starter code as you see fit, including changing the signatures of
# functions and adding/removing helper functions. However, please make sure that we can understand what you are doing and why.

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import itertools
import random

# %% [markdown]
# ## Question 1. Data (20%)
#
# Download the data from https://www.dropbox.com/s/6gdcpmfddojrl8o/data.rar?dl=0.
#
# Unzip the file. There are three
# main folders: `train`, `test_w` and `test_m`. Data in `train` will be used for
# training and validation, and the data in the other folders will be used for testing.
# This is so that the entire class will have the same test sets. The dataset is comprised of triplets of pairs, where each such triplet of image pairs was taken in a similar setting (by the same person).
#
# We've separated `test_w` and `test_m` so that we can track our model performance
# for women's shoes and men's shoes separately. Each of the test sets contain images of either exclusively men's shoes or women's
# shoes.
#
# Upload this data to Google Colab.
# Then, mount Google Drive from your Google Colab notebook:

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# After you have done so, read this entire section
# before proceeding. There are right and wrong ways of
# processing this data. If you don't make the correct choices, you may find
# yourself needing to start over.
# Many machine learning projects fail because of the lack of care taken during
# the data processing stage.

# %% [markdown]
# ### Part (a) -- 8%
#
# Load the training and test data, and separate your training data into training and validation.
# Create the numpy arrays `train_data`, `valid_data`, `test_w` and `test_m`, all of which should
# be of shape `[*, 3, 2, 224, 224, 3]`. The dimensions of these numpy arrays are as follows:
#
# - `*` - the number of triplets allocated to train, valid, or test
# - `3` - the 3 pairs of shoe images in that triplet
# - `2` - the left/right shoes
# - `224` - the height of each image
# - `224` - the width of each image
# - `3` - the colour channels
#
# So, the item `train_data[4,0,0,:,:,:]` should give us the left shoe of the first image of the fifth person.The item `train_data[4,0,1,:,:,:]`  should be the right shoe in the same pair.
# The item `train_data[4,1,1,:,:,:]`  should be the right shoe in a different pair of that same person.
#
# When you first load the images using (for example) `plt.imread`, you may see a numpy array of shape
# `[224, 224, 4]` instead of `[224, 224, 3]`. That last channel is what's called the alpha channel for transparent
# pixels, and should be removed.
# The pixel intensities are stored as an integer between 0 and 255.
# Make sure you normlize your images, namely, divide the intensities by 255 so that you have floating-point values between 0 and 1. Then, subtract 0.5
# so that the elements of `train_data`, `valid_data` and `test_data` are between -0.5 and 0.5.
# **Note that this step actually makes a huge difference in training!**
#
# This function might take a while to run; it can takes several minutes to just
# load the files from Google Drive.  If you want to avoid
# running this code multiple times, you can save
# your numpy arrays and load it later:
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.save.html

# %%
# Your code goes here. Make sure it does not get cut off
# You can use the code below to help you get started. You're welcome to modify
# the code or remove it entirely: it's just here so that you don't get stuck
# reading files

import glob
path_train = "/content/gdrive/My Drive/Colab Notebooks/data/train/*.jpg" # TODO - UPDATE ME!
path_test_m = "/content/gdrive/My Drive/Colab Notebooks/data/test_m/*.jpg" # TODO - UPDATE ME!
path_test_w = "/content/gdrive/My Drive/Colab Notebooks/data/test_w/*.jpg" # TODO - UPDATE ME!

images = [{},{},{}]

path=[path_train,path_test_m,path_test_w]
for i,pat in enumerate(path):
  for file in glob.glob(pat):
      filename = file.split("/")[-1]   # get the name of the .jpg file
      img = plt.imread(file)           # read the image as a numpy array
      images[i][filename] = (img[:, :, :3]/255-0.5) # remove the alpha channel

# %%
from matplotlib import test
#Run this code, include the image in your PDF submission
people=[[],[],[]]
for j in range(len(images)):
  for i in range(0,9):
    people[j].append(list(filter(lambda x : "u00{}".format(i) in x,images[j].keys())))
  for i in range(10,100):
    people[j].append(list(filter(lambda x : "u0{}".format(i) in x,images[j].keys())))
  for i in range(100,134):
    people[j].append(list(filter(lambda x : "u{}".format(i) in x,images[j].keys())))
  people[j] = list(people[j])
  people[j] = [x for x in people[j] if len(x)>0]
  people[j]=[sorted(sorted(x,key=lambda x:x.split('_')[2]),key=(lambda x: x.split('_')[1])) for x in people[j]]

train_data=np.ndarray(shape=(len(people[0]),3,2,224,224,3))
test_m=np.ndarray(shape=(len(people[1]),3,2,224,224,3))
test_w=np.ndarray(shape=(len(people[2]),3,2,224,224,3))
for i,pep in enumerate(people[0]):
  for j in range(3):
    for s in range(2):
      train_data[i][j][s]=images[0][pep[2*j+s]]
for i,pep in enumerate(people[1]):
  for j in range(3):
    for s in range(2):
      test_m[i][j][s]=images[1][pep[2*j+s]]
for i,pep in enumerate(people[2]):
  for j in range(3):
    for s in range(2):
      test_w[i][j][s]=images[2][pep[2*j+s]]
split_index = int(len(train_data)*0.8)
train_data, valid_data = np.split(train_data,[split_index])
print(train_data.shape)
print(valid_data.shape)
print(test_m.shape)
print(test_w.shape)
# Out:
# (88, 3, 2, 224, 224, 3)
# (23, 3, 2, 224, 224, 3)
# (10, 3, 2, 224, 224, 3)
# (10, 3, 2, 224, 224, 3)

# %%
# Run this code, include the image in your PDF submission
plt.figure()
plt.imshow(train_data[4,0,0,:,:,:]) # left shoe of first pair submitted by 5th student
plt.figure()
plt.imshow(train_data[4,0,1,:,:,:]) # right shoe of first pair submitted by 5th student
plt.figure()
plt.imshow(train_data[4,1,1,:,:,:]) # right shoe of second pair submitted by 5th student
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Part (b) -- 4%
#
# Since we want to train a model that determines whether two shoes come from the **same**
# pair or **different** pairs, we need to create some labelled training data.
# Our model will take in an image, either consisting of two shoes from the **same pair**
# or from **different pairs**. So, we'll need to generate some *positive examples* with
# images containing two shoes that *are* from the same pair, and some *negative examples* where
# images containing two shoes that *are not* from the same pair.
# We'll generate the *positive examples* in this part, and the *negative examples* in the next part.
#
# Write a function `generate_same_pair()` that takes one of the data sets that you produced
# in part (a), and generates a numpy array where each pair of shoes in the data set is
# concatenated together. In particular, we'll be concatenating together images of left
# and right shoes along the **height** axis. Your function `generate_same_pair` should
# return a  numpy array of shape `[*, 448, 224, 3]`.
#
# While at this stage we are working with numpy arrays, later on, we will need to convert this numpy array into a PyTorch tensor with shape
# `[*, 3, 448, 224]`. For now, we'll keep the RGB channel as the last dimension since
# that's what `plt.imshow` requires.

# %%
# Your code goes here
def generate_same_pair(data):
  sh=data.shape
  res=np.ndarray(shape=(sh[0]*sh[1],448,224,3))
  i=0
  for pep in data:
    for j in range(3):
      res[i]=np.concatenate((pep[j][0],pep[j][1]),axis=0)
      i+=1
  return res
# Run this code, include the result with your PDF submission
print(train_data.shape) # if this is [N, 3, 2, 224, 224, 3]
print(generate_same_pair(train_data).shape) # should be [N*3, 448, 224, 3]
plt.imshow(generate_same_pair(train_data)[0]+0.5) # should show 2 shoes from the same pair
# Out:
# (88, 3, 2, 224, 224, 3)
# (264, 448, 224, 3)

# %% [markdown]
# ### Part (c) -- 4%
#
# Write a function `generate_different_pair()` that takes one of the data sets that
# you produced in part (a), and generates a numpy array in the same shape as part (b).
# However, each image will contain 2 shoes from a **different** pair, but submitted
# by the **same student**. Do this by jumbling the 3 pairs of shoes submitted by
# each student.
#
# Theoretically, for each person (triplet of pairs), there are 6 different combinations
# of "wrong pairs" that we could produce. To keep our data set *balanced*, we will
# only produce **three** combinations of wrong pairs per unique person.
# In other words,`generate_same_pairs` and `generate_different_pairs` should
# return the same number of training examples.

# %%
# Your code goes here
def generate_different_pair(data):
  sh=data.shape
  res=np.ndarray(shape=(sh[0]*sh[1],448,224,3))
  i=0
  pairs = list(itertools.product([0, 1, 2], repeat=2))
  pairs=[pair for pair in pairs if pair[0]!=pair[1]]
  for pep in data:
    temp=random.sample(pairs, 3)
    for j in range(3):
      res[i]=np.concatenate((pep[temp[j][0]][0],pep[temp[j][1]][1]),axis=0)
      i+=1
  return res


# Run this code, include the result with your PDF submission
print(train_data.shape) # if this is [N, 3, 2, 224, 224, 3]
print(generate_different_pair(train_data).shape) # should be [N*3, 448, 224, 3]
plt.imshow(generate_different_pair(train_data)[0]+0.5) # should show 2 shoes from different pairs
# Out:
# (88, 3, 2, 224, 224, 3)
# (264, 448, 224, 3)

# %% [markdown]
# ### Part (d) -- 2%
#
# Why do we insist that the different pairs of shoes still come from the same
# person?  (Hint: what else do images from the same person have in common?)

# %% [markdown]
# **Write your explanation here:**
# We want the model's inference rule to be based on whether two shoes belong to the same pair. However, the model may find other inference rules such as whether the shoes are the same size, gender, or have the same background. By exposing the model to different shoes that do not belong to the same person, it may derive its answers based on factors such as the person's gender, shoe size, or other characteristics. This could lead to incorrect predictions or bias in the model's performance. To avoid this, it is important to ensure that the different pairs of shoes come from the same person so that the model's inference rule is based only on whether the shoes belong to the same pair.

# %% [markdown]
# ### Part (e) -- 2%
#
# Why is it important that our data set be *balanced*? In other words suppose we created
# a data set where 99% of the images are of shoes that are *not* from the same pair, and
# 1% of the images are shoes that *are* from the same pair. Why could this be a problem?

# %% [markdown]
# **Write your explanation here:**
# The Model assume always that the sample are I.I.D. from the true data distribution, but if we'll insert samples that are 99% from class A and 1% from class B, it won't reflect the true distribution (50-50).
# As a resulte, he will learnd a fake-distrubaion and will predicte almost always "class A" on the test set- but the test is indeed from the true distrubation so is 50-50.
# If 99% of our shoes are not from the same pair and only 1% are, our model tends to prioritize learning from the majority and will therefore often guess that two pictures of shoes do not depict a matching pair.

# %% [markdown]
# ## Question 2. Convolutional Neural Networks (25%)
#
# Before starting this question, we recommend reviewing the lecture and its associated example notebook on CNNs.
#
# In this section, we will build two CNN models in PyTorch.
#
# ### Part (a) -- 9%
#
# Implement a CNN model in PyTorch called `CNN` that will take images of size
# $3 \times 448 \times 224$, and classify whether the images contain shoes from
# the same pair or from different pairs.
#
# The model should contain the following layers:
#
# - A convolution layer that takes in 3 channels, and outputs $n$ channels.
# - A $2 \times 2$ downsampling (either using a strided convolution in the previous step, or max pooling)
# - A second convolution layer that takes in $n$ channels, and outputs $2\cdot n$ channels.
# - A $2 \times 2$ downsampling (either using a strided convolution in the previous step, or max pooling)
# - A third convolution layer that takes in $2\cdot n$ channels, and outputs $4\cdot n$ channels.
# - A $2 \times 2$ downsampling (either using a strided convolution in the previous step, or max pooling)
# - A fourth convolution layer that takes in $4\cdot n$ channels, and outputs $8\cdot n$ channels.
# - A $2 \times 2$ downsampling (either using a strided convolution in the previous step, or max pooling)
# - A fully-connected layer with 100 hidden units
# - A fully-connected layer with 2 hidden units
#
# Make the variable $n$ a parameter of your CNN. You can use either $3 \times 3$ or $5 \times 5$
# convolutions kernels. Set your padding to be `(kernel_size - 1) / 2` so that your feature maps
# have an even height/width.
#
# Note that we are omitting in our description certain steps that practitioners will typically not mention,
# like ReLU activations and reshaping operations. Use the example presented in class to figure out where they are.

# %%
class CNN(nn.Module):
    def __init__(self, n=4,kernel_size=3):
        super(CNN, self).__init__()
        self.n=n
        self.kernel_size=kernel_size
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=self.n, kernel_size=self.kernel_size, padding=(self.kernel_size-1)//2)
        self.conv2 = nn.Conv2d(in_channels=self.n, out_channels=2*self.n, kernel_size=self.kernel_size, padding=(self.kernel_size-1)//2)
        self.conv3 = nn.Conv2d(in_channels=2*self.n, out_channels=4*self.n, kernel_size=self.kernel_size, padding=(self.kernel_size-1)//2)
        self.conv4 = nn.Conv2d(in_channels=4*self.n, out_channels=8*self.n, kernel_size=self.kernel_size, padding=(self.kernel_size-1)//2)

        self.pool = nn.MaxPool2d(kernel_size=2)

        self.fc1 = nn.Linear(in_features=8*self.n*28*14, out_features=100)
        self.fc2 = nn.Linear(in_features=100, out_features=2)

        self.relu= nn.ReLU()
        self.softmax=nn.Softmax(dim=1)


    def forward(self, x):
        x = self.conv1(x)
        x=  self.relu(x)
        x = self.pool(x)
        x = self.conv2(x)
        x=  self.relu(x)
        x = self.pool(x)
        x = self.conv3(x)
        x=  self.relu(x)
        x = self.pool(x)
        x = self.conv4(x)
        x=  self.relu(x)
        x = self.pool(x)

        # Flatten the output of the convolutional layers
        x = x.reshape(-1,self.n*8*14*28)
        x = self.fc1(x)
        x=  self.relu(x)
        x = self.fc2(x)
        #x= self.softmax(x)
        return x

# %% [markdown]
# ### Part (b) -- 8%
#
# Implement a CNN model in PyTorch called `CNNChannel` that contains the same layers as
# in the Part (a), but with one crucial difference: instead of starting with an image
# of shape $3 \times 448 \times 224$, we will first manipulate the image so that the
# left and right shoes images are concatenated along the **channel** dimension.
#
# <img src="https://drive.google.com/uc?id=1B59VE43X-6Dw3ag-9Ndn6vPEzbnFem8K" width="400px" />
#
#
# Complete the manipulation in the `forward()` method (by slicing and using
# the function `torch.cat`). The input to the first convolutional layer
# should have 6 channels instead of 3 (input shape $6 \times 224 \times 224$).
#
# Use the same hyperparameter choices as you did in part (a), e.g. for the kernel size,
# choice of downsampling, and other choices.

# %%
class CNNChannel(nn.Module):
    def __init__(self, n=4,kernel_size=3):
        super(CNNChannel, self).__init__()
        self.n=n
        self.kernel_size=kernel_size
        self.conv1 = nn.Conv2d(in_channels=6, out_channels=self.n, kernel_size=self.kernel_size, padding=(self.kernel_size-1)//2)
        self.conv2 = nn.Conv2d(in_channels=self.n, out_channels=2*self.n, kernel_size=self.kernel_size, padding=(self.kernel_size-1)//2)
        self.conv3 = nn.Conv2d(in_channels=2*self.n, out_channels=4*self.n, kernel_size=self.kernel_size, padding=(self.kernel_size-1)//2)
        self.conv4 = nn.Conv2d(in_channels=4*self.n, out_channels=8*self.n, kernel_size=self.kernel_size, padding=(self.kernel_size-1)//2)

        self.pool = nn.MaxPool2d(kernel_size=2)

        self.fc1 = nn.Linear(in_features=8*self.n*14*14, out_features=100)
        self.fc2 = nn.Linear(in_features=100, out_features=2)

        self.relu= nn.ReLU()

    def forward(self, x):
        x= torch.cat(torch.split(x,224,dim=2),1)
        x = self.conv1(x)
        x=  self.relu(x)
        x = self.pool(x)
        x = self.conv2(x)
        x=  self.relu(x)
        x = self.pool(x)
        x = self.conv3(x)
        x=  self.relu(x)
        x = self.pool(x)
        x = self.conv4(x)
        x=  self.relu(x)
        x = self.pool(x)

        # Flatten the output of the convolutional layers
        x = x.reshape(-1,self.n*8*14*14)

        x = self.fc1(x)
        x= self.relu(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# ## Part (c) -- 4%
#
# The two models are quite similar, and should have almost the same number of parameters.
# However, one of these models will perform better, showing that architecture choices **do**
# matter in machine learning. Explain why one of these models performs better.

# %% [markdown]
# **Write your explanation here:**
# Convolutional neural networks (CNNs) are effective at processing images because they take advantage of the inherent stationarity and locality of images. This allows the network to use weight sharing and sparsity to process the data efficiently. When concatenating images along the vertical dimension, the locality of the image is disrupted along the concatenation line and the stationarity of the images is also compromised due to the different angles, patterns, lighting, etc. present in the different images. In contrast, concatenating images along the channel dimension preserves the locality and stationarity of the images, which is why the **CNNChannel model is likely to perform better than the CNN model.** The CNNChannel model can treat each channel separately, maintaining the locality and stationarity of the images, while the CNN model does not have this advantage.

# %% [markdown]
# ## Part (d) -- 4%
#
# The function `get_accuracy` is written for you. You may need to modify this
# function depending on how you set up your model and training.
#
# Unlike in the previous assignment, her we will separately compute the model accuracy on the
# positive and negative samples.  Explain why we may wish to track the false positives and false negatives separately.

# %% [markdown]
# **Write your explanation here:**
# When doing classification task, we can measure accuaracy by other measures (like Precision, Sensitivity, Recall , etc.) which can led for better understanding of the model preformence and strength or weakness.
# When we compute the model accuracy on the positive and negative samples, we obtain extra information (True Positive, False Negative, True Negative, False Positive) that we can take into our advantage, for example, when prediction medical disease, we would want our false negative to be minimized, so if we get a high accuracy, but our false negative rate is high, we didn't achieve anything.
#
# For example let's say our model's accuracy of 10 shoes is 80%, sound nice but when we look deeper we see : TP=1, FN=2, TN=7, FP=0 -> we can conculde that our model preforms like "stupid model" that just gusse "not the same pair".

# %%
def get_accuracy(model, data, batch_size=50):
    """Compute the model accuracy on the data set. This function returns two
    separate values: the model accuracy on the positive samples,
    and the model accuracy on the negative samples.

    Example Usage:

    >>> model = CNN() # create untrained model
    >>> pos_acc, neg_acc= get_accuracy(model, valid_data)
    >>> false_positive = 1 - pos_acc
    >>> false_negative = 1 - neg_acc
    """

    model.eval()
    n = data.shape[0]

    data_pos = generate_same_pair(data)      # should have shape [n * 3, 448, 224, 3]
    data_neg = generate_different_pair(data) # should have shape [n * 3, 448, 224, 3]
    pos_correct = 0
    for i in range(0, len(data_pos), batch_size):
        xs = torch.Tensor(data_pos[i:i+batch_size]).transpose(1, 3).transpose(2,3)
        zs = model(xs)
        pred = zs.max(1, keepdim=True)[1]# get the index of the max logit
        pred = pred.detach().numpy()
        pos_correct += (pred == 0).sum()
    
    neg_correct = 0
    for i in range(0, len(data_neg), batch_size):
        xs = torch.Tensor(data_neg[i:i+batch_size]).transpose(1, 3).transpose(2,3)
        zs = model(xs)
        pred = zs.max(1, keepdim=True)[1] # get the index of the max logit
        pred = pred.detach().numpy()
        neg_correct += (pred == 1).sum()

    return pos_correct / (n * 3), neg_correct / (n * 3)
model = CNN() # create untrained model
pos_acc, neg_acc= get_accuracy(model, valid_data)
false_positive = 1 - pos_acc
false_negative = 1 - neg_acc
print(pos_acc, neg_acc, false_positive, false_negative)
# Out:
# 1.0 0.0 0.0 1.0

# %% [markdown]
# ## Question 3. Training (40%)
#
# Now, we will write the functions required to train the model.
#
# Although our task is a binary classification problem, we will still use the architecture
# of a multi-class classification problem. That is, we'll use a one-hot vector to represent
# our target (like we did in the previous assignment). We'll also use `CrossEntropyLoss` instead of
# `BCEWithLogitsLoss` (this is a standard practice in machine learning because
# this architecture often performs better).
#
# ### Part (a) -- 22%
#
# Write the function `train_model` that takes in (as parameters) the model, training data,
# validation data, and other hyperparameters like the batch size, weight decay, etc.
# This function should be somewhat similar to the training code that you wrote
# in Assignment 2, but with a major difference in the way we treat our training data.
#
# Since our positive (shoes of the same pair) and negative (shoes of different pairs) training sets are separate, it is actually easier for
# us to generate separate minibatches of positive and negative training data.
#  In
# each iteration, we'll take `batch_size / 2` positive samples and `batch_size / 2`
# negative samples. We will also generate labels of 1's for the positive samples,
# and 0's for the negative samples.
#
# Here is what your training function should include:
#
# - main training loop; choice of loss function; choice of optimizer
# - obtaining the positive and negative samples
# - shuffling the positive and negative samples at the start of each epoch
# - in each iteration, take `batch_size / 2` positive samples and `batch_size / 2` negative samples
#   as our input for this batch
# - in each iteration, take `np.ones(batch_size / 2)` as the labels for the positive samples, and
#   `np.zeros(batch_size / 2)` as the labels for the negative samples
# - conversion from numpy arrays to PyTorch tensors, making sure that the input has dimensions $N \times C \times H \times W$ (known as NCHW tensor), where $N$ is the number of images batch size, $C$ is the number of channels, $H$ is the height of the image, and $W$ is the width of the image.
# - computing the forward and backward passes
# - after every epoch, report the accuracies for the training set and validation set
# - track the training curve information and plot the training curve
#
# It is also recommended to checkpoint your model (save a copy) after every epoch, as we did in Assignment 2.

# %%
# Write your code here
def shuffle(data):
  shuffled_indices = np.random.permutation(len(data))
  return data[shuffled_indices]

def train_model(model,training_data,validation_data,
                                 batch_size=50,
                                 epoch=2,
                                 learning_rate=0.001,
                                 weight_decay=0,
                                 max_iters=1000,
                                 checkpoint_path=None):
    """
    Train the PyTorch model on the dataset `train_data`, reporting
    the validation accuracy on `validation_data`, for `max_iters`
    iteration.
    This function returns the training loss, and the training/validation accuracy,
    which we can use to plot the learning curve.
    """
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(),
                           lr=learning_rate,
                           weight_decay=weight_decay)

    iters, losses = [], []
    iters_sub, train_accs, val_accs  = [], [] ,[]
    parameter=[learning_rate,weight_decay,batch_size,epoch]
    false_train_sample=generate_different_pair(training_data)
    true_train_sample=generate_same_pair(training_data)

    n = 0 # the number of iterations
    while True:
      for epoch in range(epoch):
        false_train_sample= shuffle(false_train_sample)
        true_train_sample=shuffle(true_train_sample)
        for i in range(0, true_train_sample.shape[0], batch_size//2):
          if (i + batch_size//2) > true_train_sample.shape[0]:
            break

          # get the input and targets of a minibatch
          false_batch=false_train_sample[i:i+(batch_size//2)]
          true_batch=true_train_sample[i:i+(batch_size//2)]
          #make one_hot vector as label -> [positive_labesl,negative_sample]
          true_label=np.ones((batch_size//2,2)) 
          false_label=np.ones((batch_size//2,2))
          true_label[:,1]=0
          false_label[:,0]=0
          xt=np.concatenate((false_batch,true_batch),axis=0)
          st=np.concatenate((false_label,true_label),axis=0)
          #shuffle batch
          shuff_index=np.random.permutation(len(xt))
          xt=xt[shuff_index]
          st=st[shuff_index]

          # convert from numpy arrays to PyTorch tensors
          xt = torch.Tensor(xt).transpose(1, 3).transpose(2,3)
          st = torch.Tensor(st)
          zs =  model(xt)          # compute prediction logit
          optimizer.zero_grad()    # a clean up step for PyTorch
          loss = criterion(zs,st)  # compute the total loss
          loss.backward()          # compute updates for each parameter
          optimizer.step()         # make the updates for each parameter
          # save the current training information
          iters.append(n)
          losses.append(float(loss)/batch_size)  # compute *average* loss
          # increment the iteration number
          n += 1
        #after each epoch make validation test:
        iters_sub.append(n)
        train_cost = float(loss.detach().numpy())
        train_acc_pos,train_acc_neg = get_accuracy(model, training_data,batch_size=batch_size)
        train_accs.append([train_acc_pos,train_acc_neg])
        val_acc_pos,val_acc_neg = get_accuracy(model, validation_data,batch_size=batch_size)
        val_accs.append([val_acc_pos,val_acc_neg])
        # print("Iter %d. [Val Acc of pos %.00f%% and neg %.00f%%] [Train Acc of pos %.00f%% and neg %.00f%%, Loss %f]" % (
        # n, val_acc_pos*100 ,val_acc_neg*100, train_acc_pos*100,train_acc_neg*100, train_cost))
        print("Epoch %d. Iter %d. [Val Acc  %.00f%% , TP is %.00f%%, TN is %.00f%%]\
        [Train Acc  %.00f%%,, TP is %.00f%%, TN is %.00f%%] [Loss %f]" % ( \
         epoch, n, (val_acc_pos*100+val_acc_neg*100)/2,val_acc_pos*100,\
         val_acc_neg*100,(train_acc_pos*100+train_acc_neg*100)/2,\
         train_acc_pos*100,train_acc_neg*100,train_cost))
        if (checkpoint_path is not None) and n > 0:
          torch.save(model.state_dict(), checkpoint_path.format(n))
        if n > max_iters:
          return iters, losses, iters_sub, train_accs, val_accs,parameter
      return iters, losses, iters_sub, train_accs, val_accs, parameter

# %%
def plot_learning_curve(iters, losses, iters_sub, train_accs,val_accs, parameter,save=False):
    """
    Plot the learning curve.
    """
    plt.title("Learning Curve: Loss per Iteration\
        lr={}_w={}_batch={}_ep={}.jpg".format(parameter[0],parameter[1],parameter[2],parameter[3]))
    plt.plot(iters, losses, label="Train")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")
    if save:
      plt.savefig('/content/gdrive/My Drive/Colab Notebooks/data/plot_loss={:.3f}_lr\
      ={}_w={}_batch={}_ep={}.jpg'.format(losses[-1],parameter[0],parameter[1],parameter[2],parameter[3]))
    plt.show()
    train_mean=[(tr[0]+tr[1])*0.5 for tr in train_accs]
    val_mean=[(vl[0]+vl[1])*0.5 for vl in val_accs]
    train_pos=[e[0] for e in train_accs]
    train_neg=[e[1] for e in train_accs]
    val_pos=[e[0] for e in val_accs]
    val_neg=[e[1] for e in val_accs]
    plt.title("Learning Curve: Accuracy per Iteration\
    lr={}_w={}_batch={}_ep={}.jpg".format(parameter[0],parameter[1],parameter[2],parameter[3]))
    plt.plot(iters_sub, train_mean, label="Train",lw=1.5)
    plt.plot(iters_sub, val_mean, label="Validation",lw=1.5)
    plt.plot(iters_sub,train_pos,label="TP Train",color='green',ls='--',lw='0.7')
    plt.plot(iters_sub,train_neg,label="TN Train",color='red',ls='--',lw='0.7')
    plt.plot(iters_sub,val_pos,label="TP Validation",color='green',ls=':',lw='0.7')
    plt.plot(iters_sub,train_neg,label="TN Validation",color='red',ls=':',lw='0.7')
    plt.xlabel("Iterations")
    plt.ylabel("Accuracy")
    plt.legend(loc='best')
    if save:
       plt.savefig('/content/gdrive/My Drive/Colab Notebooks/data/plot_acc={:.3f}_lr={}\
       _w={}_batch={}_ep={}.jpg'.format(train_mean[-1],parameter[0],parameter[1],parameter[2],parameter[3]))
    plt.show()

# %% [markdown]
# ### Part (b) -- 6%
#
# Sanity check your code from Q3(a) and from Q2(a) and Q2(b) by showing that your models
# can memorize a very small subset of the training set (e.g. 5 images).
# You should be able to achieve 90%+ accuracy (don't forget to calculate the accuracy)
# relatively quickly (within ~30 or so iterations).
#
#
# (Start with the second network, it is easier to converge)
#
# Try to find the general parameters combination that work for each network, it can help you a little bit later.

# %%
# Write your code here. Remember to include your results so that we can
# see that your model attains a high training accuracy. 

testModel=CNNChannel()
_,_,_,_,_=train_model(testModel,train_data[:1],valid_data[:1],batch_size=2,epoch=15,max_iters=60,learning_rate=0.001,weight_decay=0.00001)
# Out:
# Epoch 0. Iter 3. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.696407]
# Epoch 1. Iter 6. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693642]
# Epoch 2. Iter 9. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693023]
# Epoch 3. Iter 12. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.692459]
# Epoch 4. Iter 15. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.692895]
# Epoch 5. Iter 18. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.686173]
# Epoch 6. Iter 21. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  100%,, TP is 100%, TN is 100%] [Loss 0.681099]
# Epoch 7. Iter 24. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.660797]
# Epoch 8. Iter 27. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.639789]
# Epoch 9. Iter 30. [Val Acc  83% , TP is 100%, TN is 67%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.598770]
# Epoch 10. Iter 33. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.525418]
# Epoch 11. Iter 36. [Val Acc  100% , TP is 100%, TN is 100%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.636231]
# Epoch 12. Iter 39. [Val Acc  100% , TP is 100%, TN is 100%]        [Train Acc  100%,, TP is 100%, TN is 100%] [Loss 0.568131]
# Epoch 13. Iter 42. [Val Acc  83% , TP is 100%, TN is 67%]        [Train Acc  100%,, TP is 100%, TN is 100%] [Loss 0.536640]
# Epoch 14. Iter 45. [Val Acc  83% , TP is 100%, TN is 67%]        [Train Acc  100%,, TP is 100%, TN is 100%] [Loss 0.461306]

# %%
testModel=CNN()
_,_,_,_,_=train_model(testModel,train_data[:1],valid_data[:1],batch_size=2,epoch=40,max_iters=700,learning_rate=0.0005,weight_decay=0)
# Out:
# Epoch 0. Iter 3. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.695788]
# Epoch 1. Iter 6. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693792]
# Epoch 2. Iter 9. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.692479]
# Epoch 3. Iter 12. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  33%,, TP is 0%, TN is 67%] [Loss 0.692688]
# Epoch 4. Iter 15. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.690239]
# Epoch 5. Iter 18. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.690315]
# Epoch 6. Iter 21. [Val Acc  83% , TP is 100%, TN is 67%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.661307]
# Epoch 7. Iter 24. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.641005]
# Epoch 8. Iter 27. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.623732]
# Epoch 9. Iter 30. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.663112]
# Epoch 10. Iter 33. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.539976]
# Epoch 11. Iter 36. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.390825]
# Epoch 12. Iter 39. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.320235]
# Epoch 13. Iter 42. [Val Acc  83% , TP is 100%, TN is 67%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.685796]
# Epoch 14. Iter 45. [Val Acc  83% , TP is 100%, TN is 67%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.208373]
# Epoch 15. Iter 48. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.214697]
# Epoch 16. Iter 51. [Val Acc  83% , TP is 100%, TN is 67%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.508875]
# Epoch 17. Iter 54. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.405667]
# Epoch 18. Iter 57. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.253547]
# Epoch 19. Iter 60. [Val Acc  83% , TP is 100%, TN is 67%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.146336]
# Epoch 20. Iter 63. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.024564]
# Epoch 21. Iter 66. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.003181]
# Epoch 22. Iter 69. [Val Acc  83% , TP is 100%, TN is 67%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.052209]
# Epoch 23. Iter 72. [Val Acc  83% , TP is 100%, TN is 67%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.020636]
# Epoch 24. Iter 75. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.006760]
# Epoch 25. Iter 78. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.004699]
# Epoch 26. Iter 81. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  100%,, TP is 100%, TN is 100%] [Loss 0.003004]
# Epoch 27. Iter 84. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.000454]
# Epoch 28. Iter 87. [Val Acc  83% , TP is 100%, TN is 67%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.002962]
# Epoch 29. Iter 90. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  100%,, TP is 100%, TN is 100%] [Loss 0.002091]
# Epoch 30. Iter 93. [Val Acc  83% , TP is 100%, TN is 67%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.001744]
# Epoch 31. Iter 96. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.001367]
# Epoch 32. Iter 99. [Val Acc  83% , TP is 100%, TN is 67%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.000502]
# Epoch 33. Iter 102. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.000864]
# Epoch 34. Iter 105. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.000020]
# Epoch 35. Iter 108. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.000667]
# Epoch 36. Iter 111. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.000086]
# Epoch 37. Iter 114. [Val Acc  83% , TP is 100%, TN is 67%]        [Train Acc  67%,, TP is 100%, TN is 33%] [Loss 0.000287]
# Epoch 38. Iter 117. [Val Acc  83% , TP is 100%, TN is 67%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.000257]
# Epoch 39. Iter 120. [Val Acc  67% , TP is 100%, TN is 33%]        [Train Acc  83%,, TP is 100%, TN is 67%] [Loss 0.000189]

# %% [markdown]
# ### Part (c) -- 8%
#
# Train your models from Q2(a) and Q2(b). Change the values of a few
# hyperparameters, including the learning rate, batch size, choice of $n$, and
# the kernel size. You do not need to check all values for all hyperparameters. Instead, try to make big changes to see how each change affect your scores.
# (try to start with finding a resonable learning rate for each network, that start changing the other parameters, the first network might need bigger $n$ and kernel size)
#
# In this section, explain how you tuned your hyperparameters.

# %% [markdown]
# **Write your explanation here:**

# %%
# Include the training curves for the two models.
testModel=CNNChannel(kernel_size=3,n=4)
learning_curve_info=train_model(testModel,train_data,valid_data,batch_size=90,epoch=35,max_iters=1000,learning_rate=1e-3,weight_decay=1e-5)
plot_learning_curve(*learning_curve_info,save=True)
# Out:
# Epoch 0. Iter 5. [Val Acc  53% , TP is 6%, TN is 100%]        [Train Acc  52%,, TP is 9%, TN is 95%] [Loss 0.694007]
# Epoch 1. Iter 10. [Val Acc  54% , TP is 88%, TN is 19%]        [Train Acc  55%,, TP is 90%, TN is 20%] [Loss 0.693885]
# Epoch 2. Iter 15. [Val Acc  62% , TP is 54%, TN is 70%]        [Train Acc  59%,, TP is 56%, TN is 63%] [Loss 0.692273]
# Epoch 3. Iter 20. [Val Acc  65% , TP is 59%, TN is 71%]        [Train Acc  61%,, TP is 54%, TN is 67%] [Loss 0.671142]
# Epoch 4. Iter 25. [Val Acc  63% , TP is 61%, TN is 65%]        [Train Acc  61%,, TP is 60%, TN is 61%] [Loss 0.638533]
# Epoch 5. Iter 30. [Val Acc  62% , TP is 72%, TN is 52%]        [Train Acc  64%,, TP is 75%, TN is 54%] [Loss 0.673429]
# Epoch 6. Iter 35. [Val Acc  67% , TP is 55%, TN is 78%]        [Train Acc  64%,, TP is 62%, TN is 67%] [Loss 0.661100]
# Epoch 7. Iter 40. [Val Acc  69% , TP is 74%, TN is 64%]        [Train Acc  66%,, TP is 80%, TN is 52%] [Loss 0.625855]
# Epoch 8. Iter 45. [Val Acc  65% , TP is 78%, TN is 52%]        [Train Acc  68%,, TP is 87%, TN is 50%] [Loss 0.595188]
# Epoch 9. Iter 50. [Val Acc  69% , TP is 86%, TN is 52%]        [Train Acc  68%,, TP is 90%, TN is 46%] [Loss 0.591271]
# Epoch 10. Iter 55. [Val Acc  74% , TP is 71%, TN is 77%]        [Train Acc  72%,, TP is 80%, TN is 64%] [Loss 0.536259]
# Epoch 11. Iter 60. [Val Acc  71% , TP is 54%, TN is 88%]        [Train Acc  69%,, TP is 60%, TN is 78%] [Loss 0.547608]
# Epoch 12. Iter 65. [Val Acc  73% , TP is 72%, TN is 74%]        [Train Acc  74%,, TP is 77%, TN is 71%] [Loss 0.520147]
# Epoch 13. Iter 70. [Val Acc  75% , TP is 94%, TN is 55%]        [Train Acc  73%,, TP is 94%, TN is 53%] [Loss 0.523767]
# Epoch 14. Iter 75. [Val Acc  83% , TP is 84%, TN is 83%]        [Train Acc  78%,, TP is 86%, TN is 70%] [Loss 0.459584]
# Epoch 15. Iter 80. [Val Acc  81% , TP is 86%, TN is 77%]        [Train Acc  76%,, TP is 88%, TN is 65%] [Loss 0.433860]
# Epoch 16. Iter 85. [Val Acc  78% , TP is 84%, TN is 72%]        [Train Acc  78%,, TP is 85%, TN is 72%] [Loss 0.436394]
# Epoch 17. Iter 90. [Val Acc  79% , TP is 70%, TN is 88%]        [Train Acc  79%,, TP is 80%, TN is 78%] [Loss 0.498201]
# Epoch 18. Iter 95. [Val Acc  84% , TP is 87%, TN is 81%]        [Train Acc  80%,, TP is 86%, TN is 74%] [Loss 0.428173]
# Epoch 19. Iter 100. [Val Acc  80% , TP is 80%, TN is 81%]        [Train Acc  81%,, TP is 84%, TN is 78%] [Loss 0.350558]
# Epoch 20. Iter 105. [Val Acc  81% , TP is 88%, TN is 74%]        [Train Acc  84%,, TP is 93%, TN is 75%] [Loss 0.369075]
# Epoch 21. Iter 110. [Val Acc  76% , TP is 93%, TN is 59%]        [Train Acc  77%,, TP is 98%, TN is 56%] [Loss 0.340282]
# Epoch 22. Iter 115. [Val Acc  83% , TP is 90%, TN is 77%]        [Train Acc  82%,, TP is 92%, TN is 72%] [Loss 0.398393]
# Epoch 23. Iter 120. [Val Acc  83% , TP is 84%, TN is 83%]        [Train Acc  84%,, TP is 84%, TN is 83%] [Loss 0.311352]
# Epoch 24. Iter 125. [Val Acc  84% , TP is 88%, TN is 80%]        [Train Acc  83%,, TP is 94%, TN is 73%] [Loss 0.278780]
# Epoch 25. Iter 130. [Val Acc  80% , TP is 93%, TN is 68%]        [Train Acc  84%,, TP is 97%, TN is 71%] [Loss 0.327549]
# Epoch 26. Iter 135. [Val Acc  84% , TP is 88%, TN is 80%]        [Train Acc  85%,, TP is 96%, TN is 73%] [Loss 0.249818]
# Epoch 27. Iter 140. [Val Acc  83% , TP is 87%, TN is 78%]        [Train Acc  87%,, TP is 93%, TN is 81%] [Loss 0.340083]
# Epoch 28. Iter 145. [Val Acc  83% , TP is 81%, TN is 86%]        [Train Acc  87%,, TP is 88%, TN is 87%] [Loss 0.281931]
# Epoch 29. Iter 150. [Val Acc  77% , TP is 65%, TN is 88%]        [Train Acc  83%,, TP is 75%, TN is 91%] [Loss 0.217910]
# Epoch 30. Iter 155. [Val Acc  78% , TP is 64%, TN is 93%]        [Train Acc  83%,, TP is 74%, TN is 91%] [Loss 0.277103]
# Epoch 31. Iter 160. [Val Acc  82% , TP is 81%, TN is 83%]        [Train Acc  90%,, TP is 93%, TN is 86%] [Loss 0.197431]
# Epoch 32. Iter 165. [Val Acc  81% , TP is 90%, TN is 72%]        [Train Acc  87%,, TP is 97%, TN is 77%] [Loss 0.207167]
# Epoch 33. Iter 170. [Val Acc  83% , TP is 90%, TN is 75%]        [Train Acc  87%,, TP is 98%, TN is 75%] [Loss 0.242514]
# Epoch 34. Iter 175. [Val Acc  81% , TP is 87%, TN is 75%]        [Train Acc  88%,, TP is 98%, TN is 78%] [Loss 0.226094]

# %%
lr_list=[1e-5,1e-3,1e-1,0.5]
batch_list=[88,32,16]
wd_list=[0,1e-5,1e-3]
for lr in lr_list:
  for batch in batch_list:
    for wd in wd_list:
      testModel=CNNChannel(kernel_size=3,n=4)
      learning_curve_info=train_model(testModel,train_data,valid_data,batch_size=batch,epoch=30,max_iters=1000,learning_rate=lr,weight_decay=wd)
      plot_learning_curve(*learning_curve_info,save=True)
# Out:
# Epoch 0. Iter 6. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693236]
# Epoch 1. Iter 12. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693173]
# Epoch 2. Iter 18. [Val Acc  53% , TP is 17%, TN is 88%]        [Train Acc  52%,, TP is 17%, TN is 88%] [Loss 0.693068]
# Epoch 3. Iter 24. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693167]
# Epoch 4. Iter 30. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 1%, TN is 99%] [Loss 0.693021]
# Epoch 5. Iter 36. [Val Acc  52% , TP is 28%, TN is 77%]        [Train Acc  50%,, TP is 22%, TN is 79%] [Loss 0.693141]
# Epoch 6. Iter 42. [Val Acc  51% , TP is 52%, TN is 51%]        [Train Acc  54%,, TP is 61%, TN is 47%] [Loss 0.693094]
# Epoch 7. Iter 48. [Val Acc  49% , TP is 64%, TN is 33%]        [Train Acc  57%,, TP is 80%, TN is 35%] [Loss 0.693063]
# Epoch 8. Iter 54. [Val Acc  53% , TP is 67%, TN is 39%]        [Train Acc  56%,, TP is 80%, TN is 32%] [Loss 0.693044]
# Epoch 9. Iter 60. [Val Acc  51% , TP is 64%, TN is 39%]        [Train Acc  56%,, TP is 76%, TN is 36%] [Loss 0.692667]
# Epoch 10. Iter 66. [Val Acc  51% , TP is 49%, TN is 52%]        [Train Acc  56%,, TP is 60%, TN is 53%] [Loss 0.692995]
# Epoch 11. Iter 72. [Val Acc  54% , TP is 42%, TN is 67%]        [Train Acc  54%,, TP is 49%, TN is 59%] [Loss 0.692797]
# Epoch 12. Iter 78. [Val Acc  52% , TP is 42%, TN is 62%]        [Train Acc  55%,, TP is 51%, TN is 59%] [Loss 0.692737]
# Epoch 13. Iter 84. [Val Acc  54% , TP is 46%, TN is 62%]        [Train Acc  56%,, TP is 54%, TN is 58%] [Loss 0.692784]
# Epoch 14. Iter 90. [Val Acc  54% , TP is 48%, TN is 61%]        [Train Acc  56%,, TP is 57%, TN is 55%] [Loss 0.693138]
# Epoch 15. Iter 96. [Val Acc  54% , TP is 48%, TN is 59%]        [Train Acc  54%,, TP is 57%, TN is 51%] [Loss 0.692640]
# Epoch 16. Iter 102. [Val Acc  53% , TP is 49%, TN is 57%]        [Train Acc  57%,, TP is 62%, TN is 52%] [Loss 0.692405]
# Epoch 17. Iter 108. [Val Acc  55% , TP is 49%, TN is 61%]        [Train Acc  56%,, TP is 60%, TN is 53%] [Loss 0.692538]
# Epoch 18. Iter 114. [Val Acc  55% , TP is 48%, TN is 62%]        [Train Acc  56%,, TP is 59%, TN is 53%] [Loss 0.692522]
# Epoch 19. Iter 120. [Val Acc  55% , TP is 45%, TN is 65%]        [Train Acc  56%,, TP is 56%, TN is 57%] [Loss 0.692527]
# Epoch 20. Iter 126. [Val Acc  54% , TP is 48%, TN is 61%]        [Train Acc  57%,, TP is 62%, TN is 53%] [Loss 0.692464]
# Epoch 21. Iter 132. [Val Acc  54% , TP is 45%, TN is 64%]        [Train Acc  56%,, TP is 60%, TN is 52%] [Loss 0.692623]
# Epoch 22. Iter 138. [Val Acc  56% , TP is 51%, TN is 61%]        [Train Acc  57%,, TP is 64%, TN is 50%] [Loss 0.692097]
# Epoch 23. Iter 144. [Val Acc  54% , TP is 45%, TN is 62%]        [Train Acc  57%,, TP is 62%, TN is 52%] [Loss 0.692187]
# Epoch 24. Iter 150. [Val Acc  53% , TP is 45%, TN is 61%]        [Train Acc  57%,, TP is 58%, TN is 56%] [Loss 0.692038]
# Epoch 25. Iter 156. [Val Acc  53% , TP is 48%, TN is 58%]        [Train Acc  59%,, TP is 64%, TN is 55%] [Loss 0.691641]
# Epoch 26. Iter 162. [Val Acc  57% , TP is 48%, TN is 65%]        [Train Acc  59%,, TP is 63%, TN is 55%] [Loss 0.692051]
# Epoch 27. Iter 168. [Val Acc  54% , TP is 48%, TN is 61%]        [Train Acc  57%,, TP is 63%, TN is 52%] [Loss 0.692434]
# Epoch 28. Iter 174. [Val Acc  57% , TP is 48%, TN is 65%]        [Train Acc  58%,, TP is 64%, TN is 53%] [Loss 0.691357]
# Epoch 29. Iter 180. [Val Acc  56% , TP is 48%, TN is 64%]        [Train Acc  58%,, TP is 64%, TN is 53%] [Loss 0.691325]
# Epoch 0. Iter 6. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.694056]
# Epoch 1. Iter 12. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693776]
# Epoch 2. Iter 18. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693331]
# Epoch 3. Iter 24. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693201]
# Epoch 4. Iter 30. [Val Acc  49% , TP is 80%, TN is 17%]        [Train Acc  50%,, TP is 85%, TN is 14%] [Loss 0.692840]
# Epoch 5. Iter 36. [Val Acc  48% , TP is 29%, TN is 67%]        [Train Acc  51%,, TP is 23%, TN is 79%] [Loss 0.693090]
# Epoch 6. Iter 42. [Val Acc  50% , TP is 6%, TN is 94%]        [Train Acc  50%,, TP is 6%, TN is 94%] [Loss 0.693015]
# Epoch 7. Iter 48. [Val Acc  50% , TP is 3%, TN is 97%]        [Train Acc  50%,, TP is 6%, TN is 94%] [Loss 0.693199]
# Epoch 8. Iter 54. [Val Acc  49% , TP is 23%, TN is 75%]        [Train Acc  51%,, TP is 19%, TN is 83%] [Loss 0.692936]
# Epoch 9. Iter 60. [Val Acc  51% , TP is 45%, TN is 58%]        [Train Acc  51%,, TP is 47%, TN is 54%] [Loss 0.693265]
# Epoch 10. Iter 66. [Val Acc  51% , TP is 68%, TN is 35%]        [Train Acc  50%,, TP is 70%, TN is 30%] [Loss 0.693003]
# Epoch 11. Iter 72. [Val Acc  50% , TP is 75%, TN is 25%]        [Train Acc  50%,, TP is 82%, TN is 17%] [Loss 0.692986]
# Epoch 12. Iter 78. [Val Acc  51% , TP is 78%, TN is 25%]        [Train Acc  51%,, TP is 84%, TN is 18%] [Loss 0.693184]
# Epoch 13. Iter 84. [Val Acc  51% , TP is 78%, TN is 23%]        [Train Acc  51%,, TP is 87%, TN is 15%] [Loss 0.693140]
# Epoch 14. Iter 90. [Val Acc  51% , TP is 78%, TN is 25%]        [Train Acc  51%,, TP is 85%, TN is 17%] [Loss 0.693228]
# Epoch 15. Iter 96. [Val Acc  51% , TP is 77%, TN is 26%]        [Train Acc  52%,, TP is 84%, TN is 21%] [Loss 0.692988]
# Epoch 16. Iter 102. [Val Acc  53% , TP is 68%, TN is 38%]        [Train Acc  52%,, TP is 77%, TN is 27%] [Loss 0.692907]
# Epoch 17. Iter 108. [Val Acc  52% , TP is 67%, TN is 38%]        [Train Acc  53%,, TP is 72%, TN is 34%] [Loss 0.692684]
# Epoch 18. Iter 114. [Val Acc  55% , TP is 70%, TN is 41%]        [Train Acc  53%,, TP is 72%, TN is 34%] [Loss 0.692958]
# Epoch 19. Iter 120. [Val Acc  54% , TP is 68%, TN is 41%]        [Train Acc  53%,, TP is 69%, TN is 36%] [Loss 0.692826]
# Epoch 20. Iter 126. [Val Acc  56% , TP is 70%, TN is 42%]        [Train Acc  55%,, TP is 68%, TN is 41%] [Loss 0.693149]
# Epoch 21. Iter 132. [Val Acc  54% , TP is 68%, TN is 41%]        [Train Acc  54%,, TP is 65%, TN is 44%] [Loss 0.692799]
# Epoch 22. Iter 138. [Val Acc  55% , TP is 67%, TN is 43%]        [Train Acc  55%,, TP is 65%, TN is 45%] [Loss 0.692977]
# Epoch 23. Iter 144. [Val Acc  57% , TP is 68%, TN is 46%]        [Train Acc  54%,, TP is 64%, TN is 44%] [Loss 0.693201]
# Epoch 24. Iter 150. [Val Acc  57% , TP is 68%, TN is 46%]        [Train Acc  55%,, TP is 64%, TN is 46%] [Loss 0.692886]
# Epoch 25. Iter 156. [Val Acc  51% , TP is 71%, TN is 32%]        [Train Acc  56%,, TP is 65%, TN is 47%] [Loss 0.693023]
# Epoch 26. Iter 162. [Val Acc  53% , TP is 74%, TN is 32%]        [Train Acc  55%,, TP is 71%, TN is 38%] [Loss 0.692495]
# Epoch 27. Iter 168. [Val Acc  51% , TP is 74%, TN is 29%]        [Train Acc  55%,, TP is 72%, TN is 38%] [Loss 0.692775]
# Epoch 28. Iter 174. [Val Acc  55% , TP is 72%, TN is 38%]        [Train Acc  53%,, TP is 64%, TN is 42%] [Loss 0.692696]
# Epoch 29. Iter 180. [Val Acc  58% , TP is 71%, TN is 45%]        [Train Acc  54%,, TP is 64%, TN is 44%] [Loss 0.692348]
# Epoch 0. Iter 6. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.695512]
# Epoch 1. Iter 12. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.694480]
# Epoch 2. Iter 18. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.694002]
# Epoch 3. Iter 24. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693452]
# Epoch 4. Iter 30. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693461]
# Epoch 5. Iter 36. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693261]
# Epoch 6. Iter 42. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.692980]
# Epoch 7. Iter 48. [Val Acc  49% , TP is 88%, TN is 10%]        [Train Acc  50%,, TP is 97%, TN is 3%] [Loss 0.693066]
# Epoch 8. Iter 54. [Val Acc  53% , TP is 45%, TN is 61%]        [Train Acc  53%,, TP is 45%, TN is 61%] [Loss 0.693137]
# Epoch 9. Iter 60. [Val Acc  51% , TP is 16%, TN is 86%]        [Train Acc  52%,, TP is 18%, TN is 86%] [Loss 0.693048]
# Epoch 10. Iter 66. [Val Acc  51% , TP is 7%, TN is 96%]        [Train Acc  50%,, TP is 13%, TN is 88%] [Loss 0.692993]
# Epoch 11. Iter 72. [Val Acc  52% , TP is 13%, TN is 91%]        [Train Acc  52%,, TP is 17%, TN is 87%] [Loss 0.692951]
# Epoch 12. Iter 78. [Val Acc  51% , TP is 26%, TN is 75%]        [Train Acc  52%,, TP is 26%, TN is 77%] [Loss 0.692953]
# Epoch 13. Iter 84. [Val Acc  57% , TP is 39%, TN is 74%]        [Train Acc  52%,, TP is 38%, TN is 66%] [Loss 0.693102]
# Epoch 14. Iter 90. [Val Acc  50% , TP is 51%, TN is 49%]        [Train Acc  53%,, TP is 54%, TN is 52%] [Loss 0.692981]
# Epoch 15. Iter 96. [Val Acc  54% , TP is 58%, TN is 49%]        [Train Acc  55%,, TP is 64%, TN is 45%] [Loss 0.692954]
# Epoch 16. Iter 102. [Val Acc  56% , TP is 67%, TN is 45%]        [Train Acc  55%,, TP is 72%, TN is 38%] [Loss 0.693036]
# Epoch 17. Iter 108. [Val Acc  54% , TP is 68%, TN is 41%]        [Train Acc  54%,, TP is 73%, TN is 34%] [Loss 0.692976]
# Epoch 18. Iter 114. [Val Acc  54% , TP is 68%, TN is 39%]        [Train Acc  56%,, TP is 74%, TN is 39%] [Loss 0.692927]
# Epoch 19. Iter 120. [Val Acc  55% , TP is 70%, TN is 41%]        [Train Acc  55%,, TP is 73%, TN is 38%] [Loss 0.692998]
# Epoch 20. Iter 126. [Val Acc  58% , TP is 68%, TN is 48%]        [Train Acc  57%,, TP is 70%, TN is 43%] [Loss 0.693016]
# Epoch 21. Iter 132. [Val Acc  54% , TP is 64%, TN is 45%]        [Train Acc  56%,, TP is 68%, TN is 44%] [Loss 0.692937]
# Epoch 22. Iter 138. [Val Acc  56% , TP is 61%, TN is 51%]        [Train Acc  57%,, TP is 66%, TN is 48%] [Loss 0.692745]
# Epoch 23. Iter 144. [Val Acc  54% , TP is 57%, TN is 51%]        [Train Acc  54%,, TP is 59%, TN is 49%] [Loss 0.693124]
# Epoch 24. Iter 150. [Val Acc  52% , TP is 54%, TN is 51%]        [Train Acc  56%,, TP is 56%, TN is 55%] [Loss 0.693037]
# Epoch 25. Iter 156. [Val Acc  54% , TP is 55%, TN is 54%]        [Train Acc  56%,, TP is 59%, TN is 53%] [Loss 0.692764]
# Epoch 26. Iter 162. [Val Acc  55% , TP is 54%, TN is 57%]        [Train Acc  56%,, TP is 59%, TN is 53%] [Loss 0.692807]
# Epoch 27. Iter 168. [Val Acc  57% , TP is 58%, TN is 55%]        [Train Acc  57%,, TP is 60%, TN is 53%] [Loss 0.692797]
# Epoch 28. Iter 174. [Val Acc  59% , TP is 57%, TN is 62%]        [Train Acc  56%,, TP is 58%, TN is 55%] [Loss 0.692956]
# Epoch 29. Iter 180. [Val Acc  55% , TP is 57%, TN is 54%]        [Train Acc  55%,, TP is 58%, TN is 53%] [Loss 0.692641]
# Epoch 0. Iter 16. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693312]
# Epoch 1. Iter 32. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693174]
# Epoch 2. Iter 48. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693237]
# Epoch 3. Iter 64. [Val Acc  49% , TP is 97%, TN is 1%]        [Train Acc  50%,, TP is 99%, TN is 2%] [Loss 0.693069]
# Epoch 4. Iter 80. [Val Acc  50% , TP is 70%, TN is 30%]        [Train Acc  51%,, TP is 77%, TN is 25%] [Loss 0.693059]
# Epoch 5. Iter 96. [Val Acc  51% , TP is 29%, TN is 72%]        [Train Acc  51%,, TP is 31%, TN is 72%] [Loss 0.693107]
# Epoch 6. Iter 112. [Val Acc  48% , TP is 38%, TN is 58%]        [Train Acc  53%,, TP is 47%, TN is 59%] [Loss 0.693010]
# Epoch 7. Iter 128. [Val Acc  51% , TP is 38%, TN is 64%]        [Train Acc  52%,, TP is 44%, TN is 61%] [Loss 0.693225]
# Epoch 8. Iter 144. [Val Acc  50% , TP is 38%, TN is 62%]        [Train Acc  54%,, TP is 46%, TN is 61%] [Loss 0.693207]
# Epoch 9. Iter 160. [Val Acc  51% , TP is 35%, TN is 68%]        [Train Acc  52%,, TP is 36%, TN is 68%] [Loss 0.693117]
# Epoch 10. Iter 176. [Val Acc  54% , TP is 48%, TN is 59%]        [Train Acc  53%,, TP is 55%, TN is 52%] [Loss 0.693063]
# Epoch 11. Iter 192. [Val Acc  54% , TP is 55%, TN is 54%]        [Train Acc  53%,, TP is 60%, TN is 45%] [Loss 0.692957]
# Epoch 12. Iter 208. [Val Acc  50% , TP is 41%, TN is 59%]        [Train Acc  52%,, TP is 45%, TN is 60%] [Loss 0.693126]
# Epoch 13. Iter 224. [Val Acc  54% , TP is 36%, TN is 72%]        [Train Acc  52%,, TP is 36%, TN is 67%] [Loss 0.693132]
# Epoch 14. Iter 240. [Val Acc  50% , TP is 42%, TN is 58%]        [Train Acc  52%,, TP is 44%, TN is 61%] [Loss 0.693098]
# Epoch 15. Iter 256. [Val Acc  54% , TP is 45%, TN is 64%]        [Train Acc  54%,, TP is 47%, TN is 60%] [Loss 0.693008]
# Epoch 16. Iter 272. [Val Acc  55% , TP is 35%, TN is 75%]        [Train Acc  51%,, TP is 32%, TN is 70%] [Loss 0.693112]
# Epoch 17. Iter 288. [Val Acc  55% , TP is 52%, TN is 58%]        [Train Acc  54%,, TP is 50%, TN is 59%] [Loss 0.692874]
# Epoch 18. Iter 304. [Val Acc  54% , TP is 36%, TN is 71%]        [Train Acc  53%,, TP is 33%, TN is 72%] [Loss 0.693212]
# Epoch 19. Iter 320. [Val Acc  54% , TP is 38%, TN is 71%]        [Train Acc  51%,, TP is 34%, TN is 68%] [Loss 0.693108]
# Epoch 20. Iter 336. [Val Acc  53% , TP is 54%, TN is 52%]        [Train Acc  55%,, TP is 51%, TN is 60%] [Loss 0.693180]
# Epoch 21. Iter 352. [Val Acc  56% , TP is 51%, TN is 61%]        [Train Acc  55%,, TP is 44%, TN is 66%] [Loss 0.693156]
# Epoch 22. Iter 368. [Val Acc  52% , TP is 45%, TN is 59%]        [Train Acc  54%,, TP is 40%, TN is 68%] [Loss 0.693185]
# Epoch 23. Iter 384. [Val Acc  51% , TP is 35%, TN is 67%]        [Train Acc  52%,, TP is 31%, TN is 74%] [Loss 0.693166]
# Epoch 24. Iter 400. [Val Acc  55% , TP is 57%, TN is 54%]        [Train Acc  58%,, TP is 53%, TN is 62%] [Loss 0.693001]
# Epoch 25. Iter 416. [Val Acc  52% , TP is 38%, TN is 67%]        [Train Acc  51%,, TP is 31%, TN is 71%] [Loss 0.693017]
# Epoch 26. Iter 432. [Val Acc  54% , TP is 54%, TN is 55%]        [Train Acc  55%,, TP is 48%, TN is 62%] [Loss 0.693207]
# Epoch 27. Iter 448. [Val Acc  56% , TP is 46%, TN is 65%]        [Train Acc  53%,, TP is 39%, TN is 67%] [Loss 0.692808]
# Epoch 28. Iter 464. [Val Acc  53% , TP is 49%, TN is 57%]        [Train Acc  53%,, TP is 41%, TN is 66%] [Loss 0.693028]
# Epoch 29. Iter 480. [Val Acc  53% , TP is 42%, TN is 64%]        [Train Acc  54%,, TP is 34%, TN is 74%] [Loss 0.693043]
# Epoch 0. Iter 16. [Val Acc  51% , TP is 57%, TN is 45%]        [Train Acc  53%,, TP is 47%, TN is 59%] [Loss 0.692422]
# Epoch 1. Iter 32. [Val Acc  51% , TP is 72%, TN is 29%]        [Train Acc  54%,, TP is 72%, TN is 36%] [Loss 0.693077]
# Epoch 2. Iter 48. [Val Acc  56% , TP is 58%, TN is 54%]        [Train Acc  56%,, TP is 56%, TN is 56%] [Loss 0.693213]
# Epoch 3. Iter 64. [Val Acc  58% , TP is 58%, TN is 58%]        [Train Acc  56%,, TP is 53%, TN is 59%] [Loss 0.692056]
# Epoch 4. Iter 80. [Val Acc  56% , TP is 57%, TN is 55%]        [Train Acc  54%,, TP is 54%, TN is 54%] [Loss 0.692146]
# Epoch 5. Iter 96. [Val Acc  54% , TP is 62%, TN is 45%]        [Train Acc  55%,, TP is 61%, TN is 49%] [Loss 0.692880]
# Epoch 6. Iter 112. [Val Acc  54% , TP is 64%, TN is 43%]        [Train Acc  55%,, TP is 64%, TN is 47%] [Loss 0.693056]
# Epoch 7. Iter 128. [Val Acc  54% , TP is 58%, TN is 49%]        [Train Acc  56%,, TP is 53%, TN is 58%] [Loss 0.692420]
# Epoch 8. Iter 144. [Val Acc  54% , TP is 62%, TN is 45%]        [Train Acc  56%,, TP is 61%, TN is 51%] [Loss 0.693669]
# Epoch 9. Iter 160. [Val Acc  55% , TP is 61%, TN is 49%]        [Train Acc  53%,, TP is 56%, TN is 51%] [Loss 0.694887]
# Epoch 10. Iter 176. [Val Acc  54% , TP is 57%, TN is 52%]        [Train Acc  55%,, TP is 53%, TN is 56%] [Loss 0.691642]
# Epoch 11. Iter 192. [Val Acc  55% , TP is 64%, TN is 46%]        [Train Acc  54%,, TP is 60%, TN is 48%] [Loss 0.690444]
# Epoch 12. Iter 208. [Val Acc  51% , TP is 59%, TN is 43%]        [Train Acc  55%,, TP is 56%, TN is 55%] [Loss 0.692755]
# Epoch 13. Iter 224. [Val Acc  53% , TP is 61%, TN is 45%]        [Train Acc  55%,, TP is 57%, TN is 54%] [Loss 0.694918]
# Epoch 14. Iter 240. [Val Acc  54% , TP is 55%, TN is 54%]        [Train Acc  55%,, TP is 55%, TN is 54%] [Loss 0.692255]
# Epoch 15. Iter 256. [Val Acc  52% , TP is 62%, TN is 42%]        [Train Acc  55%,, TP is 61%, TN is 49%] [Loss 0.691486]
# Epoch 16. Iter 272. [Val Acc  55% , TP is 57%, TN is 54%]        [Train Acc  55%,, TP is 56%, TN is 53%] [Loss 0.690719]
# Epoch 17. Iter 288. [Val Acc  55% , TP is 57%, TN is 54%]        [Train Acc  56%,, TP is 55%, TN is 57%] [Loss 0.689506]
# Epoch 18. Iter 304. [Val Acc  57% , TP is 62%, TN is 51%]        [Train Acc  56%,, TP is 59%, TN is 52%] [Loss 0.699238]
# Epoch 19. Iter 320. [Val Acc  56% , TP is 58%, TN is 54%]        [Train Acc  56%,, TP is 56%, TN is 55%] [Loss 0.686327]
# Epoch 20. Iter 336. [Val Acc  55% , TP is 62%, TN is 48%]        [Train Acc  56%,, TP is 62%, TN is 50%] [Loss 0.696765]
# Epoch 21. Iter 352. [Val Acc  55% , TP is 57%, TN is 54%]        [Train Acc  56%,, TP is 56%, TN is 56%] [Loss 0.680889]
# Epoch 22. Iter 368. [Val Acc  52% , TP is 55%, TN is 49%]        [Train Acc  57%,, TP is 56%, TN is 58%] [Loss 0.688304]
# Epoch 23. Iter 384. [Val Acc  52% , TP is 62%, TN is 42%]        [Train Acc  57%,, TP is 62%, TN is 52%] [Loss 0.685050]
# Epoch 24. Iter 400. [Val Acc  55% , TP is 57%, TN is 54%]        [Train Acc  56%,, TP is 58%, TN is 53%] [Loss 0.690698]
# Epoch 25. Iter 416. [Val Acc  54% , TP is 54%, TN is 54%]        [Train Acc  56%,, TP is 58%, TN is 55%] [Loss 0.694817]
# Epoch 26. Iter 432. [Val Acc  55% , TP is 57%, TN is 54%]        [Train Acc  57%,, TP is 60%, TN is 54%] [Loss 0.687229]
# Epoch 27. Iter 448. [Val Acc  54% , TP is 58%, TN is 51%]        [Train Acc  57%,, TP is 60%, TN is 53%] [Loss 0.696776]
# Epoch 28. Iter 464. [Val Acc  54% , TP is 57%, TN is 51%]        [Train Acc  58%,, TP is 58%, TN is 57%] [Loss 0.693052]
# Epoch 29. Iter 480. [Val Acc  54% , TP is 54%, TN is 54%]        [Train Acc  56%,, TP is 58%, TN is 54%] [Loss 0.685006]
# Epoch 0. Iter 16. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.695324]
# Epoch 1. Iter 32. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693867]
# Epoch 2. Iter 48. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693474]
# Epoch 3. Iter 64. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693142]
# Epoch 4. Iter 80. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.692849]
# Epoch 5. Iter 96. [Val Acc  50% , TP is 4%, TN is 96%]        [Train Acc  50%,, TP is 1%, TN is 100%] [Loss 0.693329]
# Epoch 6. Iter 112. [Val Acc  52% , TP is 32%, TN is 72%]        [Train Acc  51%,, TP is 12%, TN is 91%] [Loss 0.693205]
# Epoch 7. Iter 128. [Val Acc  52% , TP is 45%, TN is 59%]        [Train Acc  54%,, TP is 43%, TN is 65%] [Loss 0.693592]
# Epoch 8. Iter 144. [Val Acc  54% , TP is 62%, TN is 45%]        [Train Acc  54%,, TP is 61%, TN is 47%] [Loss 0.693317]
# Epoch 9. Iter 160. [Val Acc  54% , TP is 65%, TN is 43%]        [Train Acc  53%,, TP is 66%, TN is 41%] [Loss 0.693628]
# Epoch 10. Iter 176. [Val Acc  56% , TP is 65%, TN is 46%]        [Train Acc  55%,, TP is 66%, TN is 43%] [Loss 0.693231]
# Epoch 11. Iter 192. [Val Acc  56% , TP is 65%, TN is 46%]        [Train Acc  54%,, TP is 64%, TN is 45%] [Loss 0.692537]
# Epoch 12. Iter 208. [Val Acc  53% , TP is 62%, TN is 43%]        [Train Acc  53%,, TP is 61%, TN is 45%] [Loss 0.692247]
# Epoch 13. Iter 224. [Val Acc  54% , TP is 65%, TN is 42%]        [Train Acc  56%,, TP is 72%, TN is 39%] [Loss 0.692736]
# Epoch 14. Iter 240. [Val Acc  51% , TP is 65%, TN is 38%]        [Train Acc  54%,, TP is 72%, TN is 36%] [Loss 0.693003]
# Epoch 15. Iter 256. [Val Acc  54% , TP is 65%, TN is 42%]        [Train Acc  55%,, TP is 67%, TN is 42%] [Loss 0.692444]
# Epoch 16. Iter 272. [Val Acc  53% , TP is 65%, TN is 41%]        [Train Acc  54%,, TP is 70%, TN is 38%] [Loss 0.692077]
# Epoch 17. Iter 288. [Val Acc  52% , TP is 65%, TN is 39%]        [Train Acc  55%,, TP is 75%, TN is 34%] [Loss 0.693564]
# Epoch 18. Iter 304. [Val Acc  53% , TP is 65%, TN is 41%]        [Train Acc  57%,, TP is 73%, TN is 41%] [Loss 0.692186]
# Epoch 19. Iter 320. [Val Acc  53% , TP is 65%, TN is 41%]        [Train Acc  54%,, TP is 72%, TN is 35%] [Loss 0.692773]
# Epoch 20. Iter 336. [Val Acc  54% , TP is 65%, TN is 42%]        [Train Acc  55%,, TP is 71%, TN is 40%] [Loss 0.693519]
# Epoch 21. Iter 352. [Val Acc  53% , TP is 65%, TN is 41%]        [Train Acc  55%,, TP is 74%, TN is 36%] [Loss 0.692374]
# Epoch 22. Iter 368. [Val Acc  55% , TP is 65%, TN is 45%]        [Train Acc  56%,, TP is 70%, TN is 42%] [Loss 0.692960]
# Epoch 23. Iter 384. [Val Acc  54% , TP is 64%, TN is 45%]        [Train Acc  55%,, TP is 70%, TN is 40%] [Loss 0.692659]
# Epoch 24. Iter 400. [Val Acc  54% , TP is 64%, TN is 45%]        [Train Acc  55%,, TP is 67%, TN is 42%] [Loss 0.692203]
# Epoch 25. Iter 416. [Val Acc  54% , TP is 61%, TN is 48%]        [Train Acc  54%,, TP is 64%, TN is 44%] [Loss 0.691762]
# Epoch 26. Iter 432. [Val Acc  56% , TP is 62%, TN is 49%]        [Train Acc  55%,, TP is 68%, TN is 42%] [Loss 0.691627]
# Epoch 27. Iter 448. [Val Acc  52% , TP is 62%, TN is 42%]        [Train Acc  55%,, TP is 67%, TN is 44%] [Loss 0.691575]
# Epoch 28. Iter 464. [Val Acc  54% , TP is 65%, TN is 42%]        [Train Acc  54%,, TP is 70%, TN is 38%] [Loss 0.691623]
# Epoch 29. Iter 480. [Val Acc  54% , TP is 67%, TN is 42%]        [Train Acc  55%,, TP is 72%, TN is 37%] [Loss 0.694071]
# Epoch 0. Iter 33. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693045]
# Epoch 1. Iter 66. [Val Acc  49% , TP is 10%, TN is 88%]        [Train Acc  50%,, TP is 3%, TN is 97%] [Loss 0.693242]
# Epoch 2. Iter 99. [Val Acc  51% , TP is 38%, TN is 65%]        [Train Acc  51%,, TP is 19%, TN is 83%] [Loss 0.693062]
# Epoch 3. Iter 132. [Val Acc  54% , TP is 41%, TN is 67%]        [Train Acc  52%,, TP is 25%, TN is 80%] [Loss 0.693096]
# Epoch 4. Iter 165. [Val Acc  50% , TP is 30%, TN is 70%]        [Train Acc  53%,, TP is 21%, TN is 84%] [Loss 0.693196]
# Epoch 5. Iter 198. [Val Acc  51% , TP is 46%, TN is 57%]        [Train Acc  53%,, TP is 41%, TN is 64%] [Loss 0.693057]
# Epoch 6. Iter 231. [Val Acc  51% , TP is 14%, TN is 88%]        [Train Acc  51%,, TP is 8%, TN is 94%] [Loss 0.693110]
# Epoch 7. Iter 264. [Val Acc  54% , TP is 57%, TN is 52%]        [Train Acc  52%,, TP is 50%, TN is 55%] [Loss 0.693179]
# Epoch 8. Iter 297. [Val Acc  54% , TP is 43%, TN is 65%]        [Train Acc  55%,, TP is 39%, TN is 72%] [Loss 0.693123]
# Epoch 9. Iter 330. [Val Acc  56% , TP is 42%, TN is 70%]        [Train Acc  56%,, TP is 39%, TN is 73%] [Loss 0.692662]
# Epoch 10. Iter 363. [Val Acc  51% , TP is 68%, TN is 35%]        [Train Acc  54%,, TP is 63%, TN is 45%] [Loss 0.692955]
# Epoch 11. Iter 396. [Val Acc  55% , TP is 51%, TN is 59%]        [Train Acc  57%,, TP is 50%, TN is 65%] [Loss 0.692041]
# Epoch 12. Iter 429. [Val Acc  54% , TP is 35%, TN is 74%]        [Train Acc  57%,, TP is 34%, TN is 81%] [Loss 0.692700]
# Epoch 13. Iter 462. [Val Acc  57% , TP is 41%, TN is 74%]        [Train Acc  57%,, TP is 41%, TN is 72%] [Loss 0.692076]
# Epoch 14. Iter 495. [Val Acc  56% , TP is 48%, TN is 64%]        [Train Acc  59%,, TP is 50%, TN is 67%] [Loss 0.694659]
# Epoch 15. Iter 528. [Val Acc  59% , TP is 54%, TN is 65%]        [Train Acc  56%,, TP is 53%, TN is 59%] [Loss 0.691620]
# Epoch 16. Iter 561. [Val Acc  54% , TP is 46%, TN is 62%]        [Train Acc  58%,, TP is 50%, TN is 67%] [Loss 0.693341]
# Epoch 17. Iter 594. [Val Acc  56% , TP is 51%, TN is 61%]        [Train Acc  57%,, TP is 54%, TN is 61%] [Loss 0.689218]
# Epoch 18. Iter 627. [Val Acc  59% , TP is 48%, TN is 70%]        [Train Acc  58%,, TP is 51%, TN is 66%] [Loss 0.691194]
# Epoch 19. Iter 660. [Val Acc  55% , TP is 49%, TN is 61%]        [Train Acc  58%,, TP is 54%, TN is 61%] [Loss 0.690055]
# Epoch 20. Iter 693. [Val Acc  57% , TP is 49%, TN is 65%]        [Train Acc  58%,, TP is 54%, TN is 61%] [Loss 0.687691]
# Epoch 21. Iter 726. [Val Acc  57% , TP is 49%, TN is 64%]        [Train Acc  57%,, TP is 54%, TN is 61%] [Loss 0.688721]
# Epoch 22. Iter 759. [Val Acc  55% , TP is 51%, TN is 59%]        [Train Acc  57%,, TP is 54%, TN is 59%] [Loss 0.691267]
# Epoch 23. Iter 792. [Val Acc  57% , TP is 49%, TN is 64%]        [Train Acc  57%,, TP is 53%, TN is 61%] [Loss 0.684258]
# Epoch 24. Iter 825. [Val Acc  57% , TP is 48%, TN is 67%]        [Train Acc  58%,, TP is 52%, TN is 65%] [Loss 0.675881]
# Epoch 25. Iter 858. [Val Acc  55% , TP is 51%, TN is 59%]        [Train Acc  56%,, TP is 55%, TN is 56%] [Loss 0.705361]
# Epoch 26. Iter 891. [Val Acc  56% , TP is 51%, TN is 61%]        [Train Acc  57%,, TP is 56%, TN is 58%] [Loss 0.672535]
# Epoch 27. Iter 924. [Val Acc  57% , TP is 61%, TN is 54%]        [Train Acc  55%,, TP is 63%, TN is 47%] [Loss 0.688494]
# Epoch 28. Iter 957. [Val Acc  58% , TP is 52%, TN is 64%]        [Train Acc  57%,, TP is 57%, TN is 58%] [Loss 0.682647]
# Epoch 29. Iter 990. [Val Acc  56% , TP is 49%, TN is 62%]        [Train Acc  57%,, TP is 55%, TN is 59%] [Loss 0.658737]
# Epoch 0. Iter 33. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693155]
# Epoch 1. Iter 66. [Val Acc  49% , TP is 1%, TN is 96%]        [Train Acc  51%,, TP is 5%, TN is 96%] [Loss 0.693126]
# Epoch 2. Iter 99. [Val Acc  49% , TP is 22%, TN is 77%]        [Train Acc  51%,, TP is 29%, TN is 74%] [Loss 0.693056]
# Epoch 3. Iter 132. [Val Acc  49% , TP is 32%, TN is 65%]        [Train Acc  52%,, TP is 45%, TN is 58%] [Loss 0.692893]
# Epoch 4. Iter 165. [Val Acc  51% , TP is 64%, TN is 38%]        [Train Acc  49%,, TP is 67%, TN is 32%] [Loss 0.692754]
# Epoch 5. Iter 198. [Val Acc  48% , TP is 22%, TN is 74%]        [Train Acc  52%,, TP is 31%, TN is 72%] [Loss 0.693275]
# Epoch 6. Iter 231. [Val Acc  55% , TP is 68%, TN is 42%]        [Train Acc  52%,, TP is 71%, TN is 34%] [Loss 0.693077]
# Epoch 7. Iter 264. [Val Acc  50% , TP is 38%, TN is 62%]        [Train Acc  52%,, TP is 47%, TN is 57%] [Loss 0.692800]
# Epoch 8. Iter 297. [Val Acc  52% , TP is 55%, TN is 49%]        [Train Acc  53%,, TP is 63%, TN is 42%] [Loss 0.693517]
# Epoch 9. Iter 330. [Val Acc  50% , TP is 29%, TN is 71%]        [Train Acc  53%,, TP is 35%, TN is 71%] [Loss 0.693251]
# Epoch 10. Iter 363. [Val Acc  51% , TP is 26%, TN is 77%]        [Train Acc  51%,, TP is 27%, TN is 75%] [Loss 0.693094]
# Epoch 11. Iter 396. [Val Acc  51% , TP is 55%, TN is 48%]        [Train Acc  57%,, TP is 64%, TN is 49%] [Loss 0.692709]
# Epoch 12. Iter 429. [Val Acc  52% , TP is 32%, TN is 72%]        [Train Acc  52%,, TP is 31%, TN is 74%] [Loss 0.693010]
# Epoch 13. Iter 462. [Val Acc  51% , TP is 46%, TN is 55%]        [Train Acc  57%,, TP is 55%, TN is 59%] [Loss 0.693306]
# Epoch 14. Iter 495. [Val Acc  49% , TP is 36%, TN is 61%]        [Train Acc  53%,, TP is 37%, TN is 69%] [Loss 0.693337]
# Epoch 15. Iter 528. [Val Acc  54% , TP is 36%, TN is 72%]        [Train Acc  54%,, TP is 36%, TN is 72%] [Loss 0.693075]
# Epoch 16. Iter 561. [Val Acc  51% , TP is 42%, TN is 61%]        [Train Acc  53%,, TP is 42%, TN is 64%] [Loss 0.693274]
# Epoch 17. Iter 594. [Val Acc  51% , TP is 41%, TN is 62%]        [Train Acc  55%,, TP is 41%, TN is 70%] [Loss 0.693331]
# Epoch 18. Iter 627. [Val Acc  54% , TP is 35%, TN is 74%]        [Train Acc  54%,, TP is 31%, TN is 76%] [Loss 0.692915]
# Epoch 19. Iter 660. [Val Acc  54% , TP is 39%, TN is 68%]        [Train Acc  54%,, TP is 38%, TN is 71%] [Loss 0.692675]
# Epoch 20. Iter 693. [Val Acc  54% , TP is 48%, TN is 59%]        [Train Acc  54%,, TP is 45%, TN is 64%] [Loss 0.692046]
# Epoch 21. Iter 726. [Val Acc  56% , TP is 46%, TN is 65%]        [Train Acc  55%,, TP is 44%, TN is 65%] [Loss 0.693069]
# Epoch 22. Iter 759. [Val Acc  52% , TP is 49%, TN is 55%]        [Train Acc  55%,, TP is 46%, TN is 64%] [Loss 0.692205]
# Epoch 23. Iter 792. [Val Acc  54% , TP is 48%, TN is 61%]        [Train Acc  55%,, TP is 44%, TN is 66%] [Loss 0.691218]
# Epoch 24. Iter 825. [Val Acc  55% , TP is 46%, TN is 64%]        [Train Acc  55%,, TP is 44%, TN is 67%] [Loss 0.690306]
# Epoch 25. Iter 858. [Val Acc  54% , TP is 46%, TN is 61%]        [Train Acc  56%,, TP is 44%, TN is 67%] [Loss 0.693097]
# Epoch 26. Iter 891. [Val Acc  54% , TP is 45%, TN is 64%]        [Train Acc  55%,, TP is 41%, TN is 70%] [Loss 0.694046]
# Epoch 27. Iter 924. [Val Acc  54% , TP is 46%, TN is 62%]        [Train Acc  56%,, TP is 44%, TN is 67%] [Loss 0.693867]
# Epoch 28. Iter 957. [Val Acc  54% , TP is 45%, TN is 64%]        [Train Acc  55%,, TP is 40%, TN is 70%] [Loss 0.692912]
# Epoch 29. Iter 990. [Val Acc  54% , TP is 46%, TN is 62%]        [Train Acc  55%,, TP is 39%, TN is 72%] [Loss 0.693666]
# Epoch 0. Iter 33. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.692849]
# Epoch 1. Iter 66. [Val Acc  51% , TP is 94%, TN is 9%]        [Train Acc  52%,, TP is 98%, TN is 6%] [Loss 0.693438]
# Epoch 2. Iter 99. [Val Acc  50% , TP is 91%, TN is 9%]        [Train Acc  49%,, TP is 93%, TN is 6%] [Loss 0.694181]
# Epoch 3. Iter 132. [Val Acc  57% , TP is 61%, TN is 52%]        [Train Acc  54%,, TP is 67%, TN is 41%] [Loss 0.693199]
# Epoch 4. Iter 165. [Val Acc  58% , TP is 59%, TN is 57%]        [Train Acc  55%,, TP is 59%, TN is 50%] [Loss 0.691705]
# Epoch 5. Iter 198. [Val Acc  54% , TP is 59%, TN is 48%]        [Train Acc  55%,, TP is 62%, TN is 48%] [Loss 0.691871]
# Epoch 6. Iter 231. [Val Acc  56% , TP is 55%, TN is 57%]        [Train Acc  57%,, TP is 56%, TN is 58%] [Loss 0.692456]
# Epoch 7. Iter 264. [Val Acc  57% , TP is 58%, TN is 55%]        [Train Acc  54%,, TP is 59%, TN is 49%] [Loss 0.689756]
# Epoch 8. Iter 297. [Val Acc  54% , TP is 55%, TN is 54%]        [Train Acc  56%,, TP is 54%, TN is 58%] [Loss 0.690896]
# Epoch 9. Iter 330. [Val Acc  57% , TP is 57%, TN is 58%]        [Train Acc  56%,, TP is 55%, TN is 58%] [Loss 0.687507]
# Epoch 10. Iter 363. [Val Acc  57% , TP is 49%, TN is 65%]        [Train Acc  56%,, TP is 49%, TN is 63%] [Loss 0.689752]
# Epoch 11. Iter 396. [Val Acc  57% , TP is 49%, TN is 64%]        [Train Acc  56%,, TP is 48%, TN is 64%] [Loss 0.684084]
# Epoch 12. Iter 429. [Val Acc  56% , TP is 54%, TN is 58%]        [Train Acc  57%,, TP is 53%, TN is 61%] [Loss 0.688185]
# Epoch 13. Iter 462. [Val Acc  55% , TP is 49%, TN is 61%]        [Train Acc  56%,, TP is 50%, TN is 62%] [Loss 0.690268]
# Epoch 14. Iter 495. [Val Acc  55% , TP is 52%, TN is 58%]        [Train Acc  57%,, TP is 52%, TN is 62%] [Loss 0.679260]
# Epoch 15. Iter 528. [Val Acc  56% , TP is 48%, TN is 64%]        [Train Acc  56%,, TP is 48%, TN is 63%] [Loss 0.699933]
# Epoch 16. Iter 561. [Val Acc  60% , TP is 54%, TN is 67%]        [Train Acc  56%,, TP is 52%, TN is 60%] [Loss 0.685155]
# Epoch 17. Iter 594. [Val Acc  55% , TP is 42%, TN is 68%]        [Train Acc  57%,, TP is 44%, TN is 70%] [Loss 0.680593]
# Epoch 18. Iter 627. [Val Acc  57% , TP is 42%, TN is 71%]        [Train Acc  59%,, TP is 45%, TN is 72%] [Loss 0.692996]
# Epoch 19. Iter 660. [Val Acc  57% , TP is 51%, TN is 64%]        [Train Acc  58%,, TP is 52%, TN is 65%] [Loss 0.689680]
# Epoch 20. Iter 693. [Val Acc  57% , TP is 49%, TN is 65%]        [Train Acc  60%,, TP is 50%, TN is 70%] [Loss 0.666390]
# Epoch 21. Iter 726. [Val Acc  57% , TP is 42%, TN is 72%]        [Train Acc  58%,, TP is 44%, TN is 72%] [Loss 0.646316]
# Epoch 22. Iter 759. [Val Acc  56% , TP is 46%, TN is 65%]        [Train Acc  59%,, TP is 48%, TN is 71%] [Loss 0.682109]
# Epoch 23. Iter 792. [Val Acc  57% , TP is 46%, TN is 68%]        [Train Acc  60%,, TP is 47%, TN is 74%] [Loss 0.671665]
# Epoch 24. Iter 825. [Val Acc  59% , TP is 54%, TN is 65%]        [Train Acc  61%,, TP is 53%, TN is 69%] [Loss 0.689015]
# Epoch 25. Iter 858. [Val Acc  60% , TP is 49%, TN is 71%]        [Train Acc  60%,, TP is 51%, TN is 69%] [Loss 0.645154]
# Epoch 26. Iter 891. [Val Acc  63% , TP is 61%, TN is 65%]        [Train Acc  62%,, TP is 58%, TN is 66%] [Loss 0.666449]
# Epoch 27. Iter 924. [Val Acc  62% , TP is 57%, TN is 67%]        [Train Acc  61%,, TP is 57%, TN is 65%] [Loss 0.701705]
# Epoch 28. Iter 957. [Val Acc  62% , TP is 55%, TN is 70%]        [Train Acc  63%,, TP is 52%, TN is 73%] [Loss 0.653889]
# Epoch 29. Iter 990. [Val Acc  61% , TP is 55%, TN is 67%]        [Train Acc  63%,, TP is 56%, TN is 70%] [Loss 0.675834]
# Epoch 0. Iter 6. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693218]
# Epoch 1. Iter 12. [Val Acc  61% , TP is 46%, TN is 75%]        [Train Acc  64%,, TP is 51%, TN is 78%] [Loss 0.688782]
# Epoch 2. Iter 18. [Val Acc  74% , TP is 88%, TN is 59%]        [Train Acc  70%,, TP is 90%, TN is 50%] [Loss 0.669603]
# Epoch 3. Iter 24. [Val Acc  83% , TP is 93%, TN is 72%]        [Train Acc  75%,, TP is 92%, TN is 58%] [Loss 0.580918]
# Epoch 4. Iter 30. [Val Acc  75% , TP is 65%, TN is 84%]        [Train Acc  79%,, TP is 76%, TN is 81%] [Loss 0.444238]
# Epoch 5. Iter 36. [Val Acc  81% , TP is 83%, TN is 80%]        [Train Acc  79%,, TP is 83%, TN is 75%] [Loss 0.465545]
# Epoch 6. Iter 42. [Val Acc  84% , TP is 87%, TN is 81%]        [Train Acc  79%,, TP is 86%, TN is 72%] [Loss 0.382234]
# Epoch 7. Iter 48. [Val Acc  86% , TP is 90%, TN is 83%]        [Train Acc  81%,, TP is 87%, TN is 76%] [Loss 0.305000]
# Epoch 8. Iter 54. [Val Acc  87% , TP is 90%, TN is 84%]        [Train Acc  83%,, TP is 85%, TN is 81%] [Loss 0.312229]
# Epoch 9. Iter 60. [Val Acc  83% , TP is 96%, TN is 71%]        [Train Acc  83%,, TP is 94%, TN is 72%] [Loss 0.402794]
# Epoch 10. Iter 66. [Val Acc  91% , TP is 94%, TN is 87%]        [Train Acc  86%,, TP is 90%, TN is 82%] [Loss 0.291319]
# Epoch 11. Iter 72. [Val Acc  90% , TP is 86%, TN is 94%]        [Train Acc  84%,, TP is 79%, TN is 89%] [Loss 0.345997]
# Epoch 12. Iter 78. [Val Acc  89% , TP is 88%, TN is 90%]        [Train Acc  86%,, TP is 82%, TN is 90%] [Loss 0.321806]
# Epoch 13. Iter 84. [Val Acc  86% , TP is 83%, TN is 88%]        [Train Acc  84%,, TP is 77%, TN is 92%] [Loss 0.334250]
# Epoch 14. Iter 90. [Val Acc  88% , TP is 93%, TN is 84%]        [Train Acc  87%,, TP is 89%, TN is 85%] [Loss 0.218232]
# Epoch 15. Iter 96. [Val Acc  88% , TP is 93%, TN is 84%]        [Train Acc  89%,, TP is 91%, TN is 87%] [Loss 0.247681]
# Epoch 16. Iter 102. [Val Acc  88% , TP is 93%, TN is 84%]        [Train Acc  88%,, TP is 88%, TN is 88%] [Loss 0.254547]
# Epoch 17. Iter 108. [Val Acc  88% , TP is 93%, TN is 83%]        [Train Acc  89%,, TP is 91%, TN is 86%] [Loss 0.230413]
# Epoch 18. Iter 114. [Val Acc  85% , TP is 90%, TN is 80%]        [Train Acc  88%,, TP is 86%, TN is 89%] [Loss 0.436655]
# Epoch 19. Iter 120. [Val Acc  89% , TP is 94%, TN is 84%]        [Train Acc  91%,, TP is 93%, TN is 88%] [Loss 0.250423]
# Epoch 20. Iter 126. [Val Acc  86% , TP is 94%, TN is 78%]        [Train Acc  89%,, TP is 92%, TN is 86%] [Loss 0.311830]
# Epoch 21. Iter 132. [Val Acc  88% , TP is 94%, TN is 81%]        [Train Acc  89%,, TP is 94%, TN is 83%] [Loss 0.254804]
# Epoch 22. Iter 138. [Val Acc  88% , TP is 93%, TN is 83%]        [Train Acc  89%,, TP is 92%, TN is 87%] [Loss 0.244636]
# Epoch 23. Iter 144. [Val Acc  88% , TP is 88%, TN is 87%]        [Train Acc  90%,, TP is 86%, TN is 94%] [Loss 0.221760]
# Epoch 24. Iter 150. [Val Acc  88% , TP is 94%, TN is 81%]        [Train Acc  92%,, TP is 96%, TN is 88%] [Loss 0.231787]
# Epoch 25. Iter 156. [Val Acc  85% , TP is 91%, TN is 78%]        [Train Acc  90%,, TP is 89%, TN is 91%] [Loss 0.250283]
# Epoch 26. Iter 162. [Val Acc  88% , TP is 90%, TN is 86%]        [Train Acc  89%,, TP is 86%, TN is 92%] [Loss 0.190741]
# Epoch 27. Iter 168. [Val Acc  88% , TP is 93%, TN is 83%]        [Train Acc  92%,, TP is 97%, TN is 87%] [Loss 0.264155]
# Epoch 28. Iter 174. [Val Acc  86% , TP is 94%, TN is 78%]        [Train Acc  88%,, TP is 98%, TN is 77%] [Loss 0.212976]
# Epoch 29. Iter 180. [Val Acc  84% , TP is 91%, TN is 77%]        [Train Acc  91%,, TP is 97%, TN is 86%] [Loss 0.175393]
# Epoch 0. Iter 6. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693475]
# Epoch 1. Iter 12. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693148]
# Epoch 2. Iter 18. [Val Acc  51% , TP is 23%, TN is 78%]        [Train Acc  55%,, TP is 22%, TN is 89%] [Loss 0.693121]
# Epoch 3. Iter 24. [Val Acc  61% , TP is 39%, TN is 83%]        [Train Acc  58%,, TP is 33%, TN is 83%] [Loss 0.691166]
# Epoch 4. Iter 30. [Val Acc  57% , TP is 51%, TN is 64%]        [Train Acc  59%,, TP is 52%, TN is 67%] [Loss 0.692676]
# Epoch 5. Iter 36. [Val Acc  64% , TP is 57%, TN is 72%]        [Train Acc  62%,, TP is 51%, TN is 73%] [Loss 0.677283]
# Epoch 6. Iter 42. [Val Acc  62% , TP is 45%, TN is 78%]        [Train Acc  64%,, TP is 50%, TN is 78%] [Loss 0.697618]
# Epoch 7. Iter 48. [Val Acc  67% , TP is 57%, TN is 77%]        [Train Acc  65%,, TP is 55%, TN is 74%] [Loss 0.654048]
# Epoch 8. Iter 54. [Val Acc  64% , TP is 52%, TN is 75%]        [Train Acc  64%,, TP is 56%, TN is 72%] [Loss 0.672060]
# Epoch 9. Iter 60. [Val Acc  68% , TP is 68%, TN is 68%]        [Train Acc  69%,, TP is 74%, TN is 64%] [Loss 0.586362]
# Epoch 10. Iter 66. [Val Acc  73% , TP is 84%, TN is 62%]        [Train Acc  69%,, TP is 81%, TN is 57%] [Loss 0.592225]
# Epoch 11. Iter 72. [Val Acc  72% , TP is 75%, TN is 70%]        [Train Acc  69%,, TP is 77%, TN is 62%] [Loss 0.618635]
# Epoch 12. Iter 78. [Val Acc  76% , TP is 78%, TN is 74%]        [Train Acc  71%,, TP is 77%, TN is 66%] [Loss 0.571868]
# Epoch 13. Iter 84. [Val Acc  75% , TP is 77%, TN is 74%]        [Train Acc  73%,, TP is 77%, TN is 68%] [Loss 0.547835]
# Epoch 14. Iter 90. [Val Acc  76% , TP is 71%, TN is 81%]        [Train Acc  73%,, TP is 67%, TN is 78%] [Loss 0.586463]
# Epoch 15. Iter 96. [Val Acc  70% , TP is 78%, TN is 61%]        [Train Acc  76%,, TP is 83%, TN is 69%] [Loss 0.518531]
# Epoch 16. Iter 102. [Val Acc  74% , TP is 75%, TN is 72%]        [Train Acc  76%,, TP is 76%, TN is 75%] [Loss 0.576420]
# Epoch 17. Iter 108. [Val Acc  73% , TP is 83%, TN is 64%]        [Train Acc  78%,, TP is 89%, TN is 67%] [Loss 0.508524]
# Epoch 18. Iter 114. [Val Acc  68% , TP is 90%, TN is 46%]        [Train Acc  75%,, TP is 94%, TN is 55%] [Loss 0.451405]
# Epoch 19. Iter 120. [Val Acc  77% , TP is 84%, TN is 70%]        [Train Acc  77%,, TP is 90%, TN is 64%] [Loss 0.427790]
# Epoch 20. Iter 126. [Val Acc  75% , TP is 86%, TN is 65%]        [Train Acc  78%,, TP is 94%, TN is 61%] [Loss 0.430936]
# Epoch 21. Iter 132. [Val Acc  75% , TP is 83%, TN is 67%]        [Train Acc  80%,, TP is 89%, TN is 70%] [Loss 0.418788]
# Epoch 22. Iter 138. [Val Acc  78% , TP is 80%, TN is 75%]        [Train Acc  81%,, TP is 86%, TN is 76%] [Loss 0.365718]
# Epoch 23. Iter 144. [Val Acc  75% , TP is 83%, TN is 68%]        [Train Acc  81%,, TP is 92%, TN is 70%] [Loss 0.332894]
# Epoch 24. Iter 150. [Val Acc  75% , TP is 91%, TN is 59%]        [Train Acc  76%,, TP is 98%, TN is 54%] [Loss 0.328602]
# Epoch 25. Iter 156. [Val Acc  76% , TP is 88%, TN is 64%]        [Train Acc  80%,, TP is 95%, TN is 64%] [Loss 0.389689]
# Epoch 26. Iter 162. [Val Acc  76% , TP is 84%, TN is 68%]        [Train Acc  82%,, TP is 94%, TN is 70%] [Loss 0.376657]
# Epoch 27. Iter 168. [Val Acc  76% , TP is 86%, TN is 67%]        [Train Acc  83%,, TP is 94%, TN is 72%] [Loss 0.319507]
# Epoch 28. Iter 174. [Val Acc  76% , TP is 81%, TN is 71%]        [Train Acc  84%,, TP is 87%, TN is 82%] [Loss 0.314828]
# Epoch 29. Iter 180. [Val Acc  79% , TP is 78%, TN is 80%]        [Train Acc  85%,, TP is 91%, TN is 78%] [Loss 0.327895]
# Epoch 0. Iter 6. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693948]
# Epoch 1. Iter 12. [Val Acc  51% , TP is 7%, TN is 96%]        [Train Acc  51%,, TP is 6%, TN is 95%] [Loss 0.692975]
# Epoch 2. Iter 18. [Val Acc  58% , TP is 49%, TN is 67%]        [Train Acc  60%,, TP is 55%, TN is 64%] [Loss 0.688033]
# Epoch 3. Iter 24. [Val Acc  64% , TP is 61%, TN is 67%]        [Train Acc  63%,, TP is 60%, TN is 66%] [Loss 0.669657]
# Epoch 4. Iter 30. [Val Acc  70% , TP is 97%, TN is 42%]        [Train Acc  69%,, TP is 97%, TN is 42%] [Loss 0.611995]
# Epoch 5. Iter 36. [Val Acc  78% , TP is 90%, TN is 65%]        [Train Acc  77%,, TP is 91%, TN is 63%] [Loss 0.526313]
# Epoch 6. Iter 42. [Val Acc  77% , TP is 64%, TN is 90%]        [Train Acc  75%,, TP is 63%, TN is 87%] [Loss 0.500444]
# Epoch 7. Iter 48. [Val Acc  80% , TP is 90%, TN is 71%]        [Train Acc  82%,, TP is 88%, TN is 75%] [Loss 0.396755]
# Epoch 8. Iter 54. [Val Acc  80% , TP is 62%, TN is 97%]        [Train Acc  78%,, TP is 64%, TN is 91%] [Loss 0.604555]
# Epoch 9. Iter 60. [Val Acc  79% , TP is 94%, TN is 64%]        [Train Acc  79%,, TP is 95%, TN is 63%] [Loss 0.476728]
# Epoch 10. Iter 66. [Val Acc  86% , TP is 83%, TN is 88%]        [Train Acc  82%,, TP is 81%, TN is 83%] [Loss 0.436414]
# Epoch 11. Iter 72. [Val Acc  83% , TP is 86%, TN is 81%]        [Train Acc  81%,, TP is 83%, TN is 79%] [Loss 0.428469]
# Epoch 12. Iter 78. [Val Acc  80% , TP is 75%, TN is 84%]        [Train Acc  81%,, TP is 79%, TN is 84%] [Loss 0.404362]
# Epoch 13. Iter 84. [Val Acc  83% , TP is 75%, TN is 90%]        [Train Acc  80%,, TP is 68%, TN is 92%] [Loss 0.438513]
# Epoch 14. Iter 90. [Val Acc  86% , TP is 75%, TN is 96%]        [Train Acc  81%,, TP is 73%, TN is 89%] [Loss 0.317664]
# Epoch 15. Iter 96. [Val Acc  84% , TP is 90%, TN is 78%]        [Train Acc  85%,, TP is 89%, TN is 81%] [Loss 0.262072]
# Epoch 16. Iter 102. [Val Acc  85% , TP is 88%, TN is 81%]        [Train Acc  85%,, TP is 90%, TN is 80%] [Loss 0.335860]
# Epoch 17. Iter 108. [Val Acc  86% , TP is 87%, TN is 84%]        [Train Acc  83%,, TP is 84%, TN is 83%] [Loss 0.363248]
# Epoch 18. Iter 114. [Val Acc  83% , TP is 77%, TN is 90%]        [Train Acc  84%,, TP is 77%, TN is 91%] [Loss 0.374660]
# Epoch 19. Iter 120. [Val Acc  83% , TP is 77%, TN is 88%]        [Train Acc  86%,, TP is 79%, TN is 92%] [Loss 0.424842]
# Epoch 20. Iter 126. [Val Acc  87% , TP is 94%, TN is 80%]        [Train Acc  84%,, TP is 95%, TN is 73%] [Loss 0.341186]
# Epoch 21. Iter 132. [Val Acc  88% , TP is 94%, TN is 83%]        [Train Acc  86%,, TP is 95%, TN is 77%] [Loss 0.367380]
# Epoch 22. Iter 138. [Val Acc  86% , TP is 93%, TN is 80%]        [Train Acc  86%,, TP is 94%, TN is 78%] [Loss 0.276878]
# Epoch 23. Iter 144. [Val Acc  83% , TP is 94%, TN is 72%]        [Train Acc  86%,, TP is 96%, TN is 76%] [Loss 0.236213]
# Epoch 24. Iter 150. [Val Acc  82% , TP is 88%, TN is 75%]        [Train Acc  88%,, TP is 92%, TN is 84%] [Loss 0.226922]
# Epoch 25. Iter 156. [Val Acc  86% , TP is 88%, TN is 84%]        [Train Acc  87%,, TP is 94%, TN is 80%] [Loss 0.391360]
# Epoch 26. Iter 162. [Val Acc  83% , TP is 94%, TN is 71%]        [Train Acc  80%,, TP is 97%, TN is 63%] [Loss 0.371822]
# Epoch 27. Iter 168. [Val Acc  81% , TP is 96%, TN is 67%]        [Train Acc  77%,, TP is 99%, TN is 56%] [Loss 0.268697]
# Epoch 28. Iter 174. [Val Acc  83% , TP is 94%, TN is 72%]        [Train Acc  83%,, TP is 97%, TN is 70%] [Loss 0.413721]
# Epoch 29. Iter 180. [Val Acc  84% , TP is 97%, TN is 71%]        [Train Acc  80%,, TP is 97%, TN is 63%] [Loss 0.321848]
# Epoch 0. Iter 16. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693184]
# Epoch 1. Iter 32. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693171]
# Epoch 2. Iter 48. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.692020]
# Epoch 3. Iter 64. [Val Acc  78% , TP is 83%, TN is 72%]        [Train Acc  72%,, TP is 80%, TN is 64%] [Loss 0.628600]
# Epoch 4. Iter 80. [Val Acc  67% , TP is 35%, TN is 99%]        [Train Acc  66%,, TP is 35%, TN is 97%] [Loss 0.590476]
# Epoch 5. Iter 96. [Val Acc  83% , TP is 74%, TN is 91%]        [Train Acc  80%,, TP is 70%, TN is 89%] [Loss 0.397985]
# Epoch 6. Iter 112. [Val Acc  86% , TP is 81%, TN is 91%]        [Train Acc  83%,, TP is 80%, TN is 86%] [Loss 0.425168]
# Epoch 7. Iter 128. [Val Acc  81% , TP is 93%, TN is 70%]        [Train Acc  80%,, TP is 95%, TN is 66%] [Loss 0.367245]
# Epoch 8. Iter 144. [Val Acc  82% , TP is 93%, TN is 71%]        [Train Acc  83%,, TP is 95%, TN is 72%] [Loss 0.272146]
# Epoch 9. Iter 160. [Val Acc  85% , TP is 83%, TN is 87%]        [Train Acc  87%,, TP is 84%, TN is 89%] [Loss 0.392834]
# Epoch 10. Iter 176. [Val Acc  83% , TP is 93%, TN is 74%]        [Train Acc  84%,, TP is 94%, TN is 73%] [Loss 0.284896]
# Epoch 11. Iter 192. [Val Acc  85% , TP is 86%, TN is 84%]        [Train Acc  87%,, TP is 86%, TN is 88%] [Loss 0.324295]
# Epoch 12. Iter 208. [Val Acc  90% , TP is 94%, TN is 86%]        [Train Acc  86%,, TP is 94%, TN is 78%] [Loss 0.358551]
# Epoch 13. Iter 224. [Val Acc  83% , TP is 87%, TN is 78%]        [Train Acc  90%,, TP is 92%, TN is 88%] [Loss 0.248386]
# Epoch 14. Iter 240. [Val Acc  81% , TP is 90%, TN is 72%]        [Train Acc  88%,, TP is 94%, TN is 81%] [Loss 0.190307]
# Epoch 15. Iter 256. [Val Acc  82% , TP is 87%, TN is 77%]        [Train Acc  90%,, TP is 94%, TN is 85%] [Loss 0.247723]
# Epoch 16. Iter 272. [Val Acc  86% , TP is 88%, TN is 83%]        [Train Acc  91%,, TP is 95%, TN is 87%] [Loss 0.232382]
# Epoch 17. Iter 288. [Val Acc  83% , TP is 94%, TN is 72%]        [Train Acc  84%,, TP is 98%, TN is 70%] [Loss 0.247273]
# Epoch 18. Iter 304. [Val Acc  82% , TP is 90%, TN is 74%]        [Train Acc  88%,, TP is 97%, TN is 78%] [Loss 0.186626]
# Epoch 19. Iter 320. [Val Acc  84% , TP is 81%, TN is 87%]        [Train Acc  93%,, TP is 92%, TN is 93%] [Loss 0.167456]
# Epoch 20. Iter 336. [Val Acc  84% , TP is 83%, TN is 86%]        [Train Acc  93%,, TP is 96%, TN is 90%] [Loss 0.187813]
# Epoch 21. Iter 352. [Val Acc  78% , TP is 84%, TN is 72%]        [Train Acc  94%,, TP is 98%, TN is 89%] [Loss 0.110966]
# Epoch 22. Iter 368. [Val Acc  81% , TP is 81%, TN is 81%]        [Train Acc  93%,, TP is 98%, TN is 89%] [Loss 0.190031]
# Epoch 23. Iter 384. [Val Acc  85% , TP is 84%, TN is 86%]        [Train Acc  93%,, TP is 98%, TN is 89%] [Loss 0.181262]
# Epoch 24. Iter 400. [Val Acc  82% , TP is 83%, TN is 81%]        [Train Acc  95%,, TP is 99%, TN is 91%] [Loss 0.133232]
# Epoch 25. Iter 416. [Val Acc  86% , TP is 90%, TN is 83%]        [Train Acc  91%,, TP is 100%, TN is 83%] [Loss 0.079324]
# Epoch 26. Iter 432. [Val Acc  86% , TP is 81%, TN is 91%]        [Train Acc  94%,, TP is 99%, TN is 90%] [Loss 0.084413]
# Epoch 27. Iter 448. [Val Acc  83% , TP is 87%, TN is 78%]        [Train Acc  94%,, TP is 100%, TN is 88%] [Loss 0.107240]
# Epoch 28. Iter 464. [Val Acc  80% , TP is 81%, TN is 78%]        [Train Acc  96%,, TP is 100%, TN is 91%] [Loss 0.082102]
# Epoch 29. Iter 480. [Val Acc  80% , TP is 77%, TN is 84%]        [Train Acc  96%,, TP is 100%, TN is 93%] [Loss 0.038421]
# Epoch 0. Iter 16. [Val Acc  49% , TP is 1%, TN is 97%]        [Train Acc  50%,, TP is 1%, TN is 100%] [Loss 0.692699]
# Epoch 1. Iter 32. [Val Acc  65% , TP is 78%, TN is 52%]        [Train Acc  61%,, TP is 75%, TN is 47%] [Loss 0.616406]
# Epoch 2. Iter 48. [Val Acc  70% , TP is 100%, TN is 41%]        [Train Acc  66%,, TP is 96%, TN is 36%] [Loss 0.611067]
# Epoch 3. Iter 64. [Val Acc  64% , TP is 70%, TN is 59%]        [Train Acc  70%,, TP is 76%, TN is 63%] [Loss 0.770892]
# Epoch 4. Iter 80. [Val Acc  69% , TP is 93%, TN is 45%]        [Train Acc  68%,, TP is 95%, TN is 41%] [Loss 0.544222]
# Epoch 5. Iter 96. [Val Acc  70% , TP is 87%, TN is 52%]        [Train Acc  73%,, TP is 88%, TN is 57%] [Loss 0.484635]
# Epoch 6. Iter 112. [Val Acc  70% , TP is 88%, TN is 51%]        [Train Acc  73%,, TP is 91%, TN is 55%] [Loss 0.512309]
# Epoch 7. Iter 128. [Val Acc  66% , TP is 94%, TN is 38%]        [Train Acc  68%,, TP is 97%, TN is 39%] [Loss 0.639075]
# Epoch 8. Iter 144. [Val Acc  78% , TP is 83%, TN is 74%]        [Train Acc  75%,, TP is 84%, TN is 65%] [Loss 0.375390]
# ...
# Epoch 18. Iter 304. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 19. Iter 320. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 20. Iter 336. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 21. Iter 352. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 22. Iter 368. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 23. Iter 384. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693147]
# Epoch 24. Iter 400. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 25. Iter 416. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 26. Iter 432. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 27. Iter 448. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 28. Iter 464. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 29. Iter 480. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 0. Iter 16. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.700423]
# Epoch 1. Iter 32. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.694661]
# Epoch 2. Iter 48. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.716678]
# Epoch 3. Iter 64. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.745251]
# Epoch 4. Iter 80. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.696806]
# Epoch 5. Iter 96. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693197]
# Epoch 6. Iter 112. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693148]
# Epoch 7. Iter 128. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 1.341309]
# Epoch 8. Iter 144. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.715626]
# Epoch 9. Iter 160. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.696582]
# Epoch 10. Iter 176. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.717526]
# Epoch 11. Iter 192. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 1.382530]
# Epoch 12. Iter 208. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.695044]
# Epoch 13. Iter 224. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.694097]
# Epoch 14. Iter 240. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693813]
# Epoch 15. Iter 256. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.717202]
# Epoch 16. Iter 272. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.706913]
# Epoch 17. Iter 288. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.723489]
# Epoch 18. Iter 304. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693739]
# Epoch 19. Iter 320. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693563]
# Epoch 20. Iter 336. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693499]
# Epoch 21. Iter 352. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693194]
# Epoch 22. Iter 368. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 23. Iter 384. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693149]
# Epoch 24. Iter 400. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 25. Iter 416. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693147]
# Epoch 26. Iter 432. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693147]
# Epoch 27. Iter 448. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693147]
# Epoch 28. Iter 464. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693170]
# Epoch 29. Iter 480. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693147]
# Epoch 0. Iter 33. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.696476]
# Epoch 1. Iter 66. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.694277]
# Epoch 2. Iter 99. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693176]
# Epoch 3. Iter 132. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693148]
# Epoch 4. Iter 165. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693147]
# Epoch 5. Iter 198. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 6. Iter 231. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693147]
# Epoch 7. Iter 264. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693147]
# Epoch 8. Iter 297. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693147]
# Epoch 9. Iter 330. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 10. Iter 363. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 11. Iter 396. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 12. Iter 429. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 13. Iter 462. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 14. Iter 495. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 15. Iter 528. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 16. Iter 561. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 17. Iter 594. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 18. Iter 627. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 19. Iter 660. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 20. Iter 693. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 21. Iter 726. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 22. Iter 759. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 23. Iter 792. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 24. Iter 825. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 25. Iter 858. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 26. Iter 891. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 27. Iter 924. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 28. Iter 957. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 29. Iter 990. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 0. Iter 33. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.696474]
# Epoch 1. Iter 66. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 1.204422]
# Epoch 2. Iter 99. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.721991]
# Epoch 3. Iter 132. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693416]
# Epoch 4. Iter 165. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693166]
# Epoch 5. Iter 198. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693148]
# Epoch 6. Iter 231. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693147]
# Epoch 7. Iter 264. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693147]
# Epoch 8. Iter 297. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693147]
# Epoch 9. Iter 330. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 10. Iter 363. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 11. Iter 396. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.705068]
# Epoch 12. Iter 429. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.699856]
# Epoch 13. Iter 462. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.706154]
# Epoch 14. Iter 495. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693359]
# Epoch 15. Iter 528. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.720887]
# Epoch 16. Iter 561. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.697016]
# Epoch 17. Iter 594. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.694138]
# Epoch 18. Iter 627. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.699783]
# Epoch 19. Iter 660. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.712405]
# Epoch 20. Iter 693. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 3.265626]
# Epoch 21. Iter 726. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 1.169743]
# Epoch 22. Iter 759. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.868448]
# Epoch 23. Iter 792. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.786914]
# Epoch 24. Iter 825. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693346]
# Epoch 25. Iter 858. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693165]
# Epoch 26. Iter 891. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693148]
# Epoch 27. Iter 924. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693147]
# Epoch 28. Iter 957. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 29. Iter 990. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693147]
# Epoch 0. Iter 33. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 3.179418]
# Epoch 1. Iter 66. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.737216]
# Epoch 2. Iter 99. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693148]
# Epoch 3. Iter 132. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693149]
# Epoch 4. Iter 165. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693154]
# Epoch 5. Iter 198. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 6. Iter 231. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693148]
# Epoch 7. Iter 264. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693188]
# Epoch 8. Iter 297. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693477]
# Epoch 9. Iter 330. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.989400]
# Epoch 10. Iter 363. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.927737]
# Epoch 11. Iter 396. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.694101]
# Epoch 12. Iter 429. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693163]
# Epoch 13. Iter 462. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693153]
# Epoch 14. Iter 495. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 15. Iter 528. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693148]
# Epoch 16. Iter 561. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693147]
# Epoch 17. Iter 594. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693148]
# Epoch 18. Iter 627. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.693150]
# Epoch 19. Iter 660. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693160]
# Epoch 20. Iter 693. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.698307]
# Epoch 21. Iter 726. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.902548]
# Epoch 22. Iter 759. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 1.423324]
# Epoch 23. Iter 792. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 2.103014]
# Epoch 24. Iter 825. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 1.437137]
# Epoch 25. Iter 858. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.794842]
# Epoch 26. Iter 891. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.956526]
# Epoch 27. Iter 924. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 1.026613]
# Epoch 28. Iter 957. [Val Acc  50% , TP is 0%, TN is 100%]        [Train Acc  50%,, TP is 0%, TN is 100%] [Loss 0.750022]
# Epoch 29. Iter 990. [Val Acc  50% , TP is 100%, TN is 0%]        [Train Acc  50%,, TP is 100%, TN is 0%] [Loss 0.693196]

# %% [markdown]
# ### Part (d) -- 4%
#
# Include your training curves for the **best** models from each of Q2(a) and Q2(b).
# These are the models that you will use in Question 4.

# %%
# Include the training curves for the two models.

# %% [markdown]
# ## Question 4. Testing (15%)
#
# ### Part (a) -- 7%
#
# Report the test accuracies of your **single best** model,
# separately for the two test sets.
# Do this by choosing the  model
# architecture that produces the best validation accuracy. For instance,
# if your model attained the
# best validation accuracy in epoch 12, then the weights at epoch 12 is what you should be using
# to report the test accuracy.

# %%
# Write your code here. Make sure to include the test accuracy in your report

# %% [markdown]
# ### Part (b) -- 4%
#
# Display one set of men's shoes that your model correctly classified as being
# from the same pair.
#
# If your test accuracy was not 100% on the men's shoes test set,
# display one set of inputs that your model classified incorrectly.

# %% [markdown]
# ### Part (c) -- 4%
#
# Display one set of women's shoes that your model correctly classified as being
# from the same pair.
#
# If your test accuracy was not 100% on the women's shoes test set,
# display one set of inputs that your model classified incorrectly.
